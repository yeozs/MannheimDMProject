# %%
## Imports and constants
import os
import sys

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import gensim.downloader as api

import matplotlib.pyplot as plt
import seaborn as sns

import datetime
import warnings

from preprocessing import lstm_preprocessing
from zm_lstm_helper import *
from zm_lstm_model import SimpleLSTM

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.manual_seed(20) 
np.random.seed(20)

MAX_SEQ_LEN = 200
BATCH_SIZE = 10

warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv(os.getcwd() + '/processed_data.csv')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
dataset = dataset.head(20)

# %%
import pandas as pd
import numpy as np
import random
import string
from nltk.tokenize import word_tokenize
import gensim.downloader as api

# Function for removing punctuations
def _remove_punc(review):
    ascii_to_translate = str.maketrans("", "", string.punctuation)
    review = review.translate(ascii_to_translate)
    return review

# Function for GloVe vectorization
def _glove_embed(tokenized_reviews):
    glove_model = api.load("glove-wiki-gigaword-50")

    rev_tokenized_embedded = []
    unidentified_tokens = []  # Tokens not in GloVe model

    for review in tokenized_reviews:
        curr_embedded_review = []
        for token in review:
            if token in glove_model:
                curr_embedded_review.append(glove_model[token])
            else:
                unidentified_tokens.append(token)
        rev_tokenized_embedded.append(curr_embedded_review)
    print(f'{len(unidentified_tokens)} total tokens not in GloVe model.')

    return rev_tokenized_embedded

# Function to preprocess reviews for LSTM
def lstm_preprocessing(reviews: pd.Series, tokenizer=word_tokenize):
    random.seed(20)
    np.random.seed(20)

    # Ensure the reviews are of type string
    reviews = reviews.astype(str)

    # Remove Punctuation
    reviews_list_noPunc = [_remove_punc(review) for review in reviews]

    # Make text all lowercase
    reviews_list_lower = [review.lower() for review in reviews_list_noPunc]

    # Tokenization
    rev_tokenized = [tokenizer(review) for review in reviews_list_lower]

    # GloVe Vectorization
    rev_tokenized_embedded = _glove_embed(rev_tokenized)

    # Return a new Series with preprocessed reviews
    preprocessed_reviews = pd.Series(rev_tokenized_embedded, index=reviews.index)

    return preprocessed_reviews

# %%
## Preprocessing using common preprocessing function
dataset['Reviews_5'] = lstm_preprocessing(dataset['Reviews'])
# Out:
# 19 total tokens not in GloVe model.

# %%
dataset
# Out:
#                                            Title              Name  \
# 0                             Flight was amazing  Alison Soetantyo
# 1           seats on this aircraft are dreadful      Robert Watson
# 2                   Food was plentiful and tasty             S Han
# 3                   “how much food was available          D Laynes
# 4                “service was consistently good”         A Othman
# 5                  “seat is absolutely dreadful”     Robert Watson
# 6                          Very ordinary service          S Holger
# 7                     I like flying this airline           A Jabil
# 8                    left me deeply disappointed        A Kalarsan
# 9                   can’t fault a single aspect            S Dayle
# 10                          No complaints at all          J Hassin
# 11                             “I was impressed”           N Allen
# 12                              “Superb service”           N Allen
# 13        regional seat was really uncomfortable             L Hee
# 14                      “no problems whatsoever”         Jason Keh
# 15             crew serving business disappeared          C Harmon
# 16  agent took out travel insurance on my behalf       Niki Kladis
# 17                       one of the best flights          E Darlon
# 18                    “received amazing support”        B Morrison
# 19               not fly with them in the future           H Paran
#
#    Review Date             Airline Verified  \
# 0   2024-03-01  Singapore Airlines     True
# 1   2024-02-21  Singapore Airlines     True
# 2   2024-02-20  Singapore Airlines     True
# 3   2024-02-19  Singapore Airlines     True
# 4   2024-02-19  Singapore Airlines     True
# 5   2024-02-19  Singapore Airlines     True
# 6   2024-02-19  Singapore Airlines     True
# 7   2024-02-19  Singapore Airlines     True
# 8   2024-02-18  Singapore Airlines     True
# 9   2024-02-17  Singapore Airlines     True
# 10  2024-02-17  Singapore Airlines     True
# 11  2024-02-16  Singapore Airlines     True
# 12  2024-02-16  Singapore Airlines     True
# 13  2024-02-16  Singapore Airlines     True
# 14  2024-02-09  Singapore Airlines    False
# 15  2024-02-01  Singapore Airlines     True
# 16  2024-01-29  Singapore Airlines     True
# 17  2024-01-25  Singapore Airlines     True
# 18  2024-01-19  Singapore Airlines     True
# 19  2024-01-18  Singapore Airlines     True
#
#                                               Reviews Type of Traveller  \
# 0     Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1     Booking an emergency exit seat still meant h...      Solo Leisure
# 2     Excellent performance on all fronts. I would...    Family Leisure
# 3    Pretty comfortable flight considering I was f...      Solo Leisure
# 4    The service was consistently good from start ...    Family Leisure
# 5    This flight was over six hours long on a B737...      Solo Leisure
# 6     Boarding process went smoothly, and plane le...      Solo Leisure
# 7     Pleasant flight which operated on time. Chec...    Family Leisure
# 8     I embarked on a journey with high hopes and ...          Business
# 9     No queue at check-in, and boarding at the ga...    Family Leisure
# 10    Competitive pricing on this route. Service i...      Solo Leisure
# 11   This was my first time flying on a regional S...    Family Leisure
# 12   Superb service even in economy class. Nothing...      Solo Leisure
# 13    I was one of the last business class passeng...      Solo Leisure
# 14    The flight is very smooth sailing, no proble...    Family Leisure
# 15    I flew Perth to Hong Kong via Singapore on S...      Solo Leisure
# 16    For my final trip booked for July 2024, Sing...      Solo Leisure
# 17    Booked a wheelchair service from Milan to Ba...      Solo Leisure
# 18   I initially booked two separate flights for t...      Solo Leisure
# 19    I flew on SQ217 from Singapore to Melbourne ...    Couple Leisure
#
#       Month Flown                             Route           Class  \
# 0   December 2023              Jakarta to Singapore  Business Class
# 1   February 2024               Phuket to Singapore   Economy Class
# 2   February 2024            Siem Reap to Singapore   Economy Class
# 3   February 2024      Singapore to London Heathrow   Economy Class
# 4   February 2024           Singapore to Phnom Penh   Economy Class
# 5   February 2024               Singapore to Cairns   Economy Class
# 6   February 2024            Singapore to Frankfurt   Economy Class
# 7   February 2024  Singapore to Bandar Seri Begawan   Economy Class
# 8   February 2024              Singapore to Jakarta   Economy Class
# 9   February 2024            Siem Reap to Singapore   Economy Class
# 10  February 2024  Bandar Seri Begawan to Singapore   Economy Class
# 11  February 2024           Singapore to Phnom Penh   Economy Class
# 12  February 2024      London Heathrow to Singapore   Economy Class
# 13   January 2024         Singapore to Tokyo Haneda  Business Class
# 14  February 2024            Singapore to Hong Kong  Business Class
# 15   January 2024  Perth to Hong Kong via Singapore  Business Class
# 16  December 2023  Sydney to Istanbul via Singapore  Business Class
# 17   January 2024    Milan to Bangkok via Singapore   Economy Class
# 18  November 2023    London to Manila via Singapore   Economy Class
# 19   January 2024            Singapore to Melbourne   Economy Class
#
#     Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 0              4              4                 4                       4
# 1              5              3                 4                       4
# 2              1              5                 2                       1
# 3              5              5                 5                       5
# 4              5              5                 5                       5
# 5              5              1                 5                       5
# 6              1              3                 1                       2
# 7              2              5                 3                       4
# 8              5              4                 5                       5
# 9              4              5                 4                       3
# 10             5              5                 5                       5
# 11             5              5                 5                       5
# 12             4              5                 5                       5
# 13             5              1                 5                       5
# 14             1              5                 4                       5
# 15             5              4                 5                       4
# 16             4              5                 4                       5
# 17             4              5                 5                       5
# 18             5              1                 5                       5
# 19             1              1                 1                       1
#
#     Value For Money Recommended  Sentiment  Year  review_length  \
# 0                 4         yes          2  2024            467
# 1                 1          no          0  2024            249
# 2                 5         yes          2  2024            196
# 3                 5         yes          2  2024            991
# 4                 5         yes          2  2024            310
# 5                 1          no          0  2024            812
# 6                 2          no          1  2024            866
# 7                 5         yes          2  2024            284
# 8                 3          no          0  2024           1933
# 9                 5         yes          2  2024            502
# 10                5         yes          2  2024            172
# 11                4         yes          2  2024            454
# 12                5         yes          2  2024            249
# 13                3         yes          0  2024            757
# 14                5         yes          2  2024            444
# 15                4         yes          2  2024            559
# 16                3          no          0  2024            663
# 17                5         yes          2  2024            708
# 18                5         yes          2  2024            968
# 19                1          no          0  2024           1805
#
#                                             Reviews_1  \
# 0   Flight amazing. The crew onboard flight welcom...
# 1   Booking emergency exit seat still meant huge d...
# 2   Excellent performance fronts. I would definite...
# 3   Pretty comfortable flight considering I flying...
# 4   The service consistently good start finish. Th...
# 5   This flight six hours long B737 MAX8. I booked...
# 6   Boarding process went smoothly, plane left tim...
# 7   Pleasant flight operated time. Check-in Changi...
# 8   I embarked journey high hopes anticipation, se...
# 9   No queue check-in, boarding gate done orderly ...
# 10  Competitive pricing route. Service reliable fr...
# 11  This first time flying regional Singapore Airl...
# 12  Superb service even economy class. Nothing muc...
# 13  I one last business class passengers board, We...
# 14  The flight smooth sailing, problems whatsoever...
# 15  I flew Perth Hong Kong via Singapore SQ226/896...
# 16  For final trip booked July 2024, Singapore can...
# 17  Booked wheelchair service Milan Bangkok. Apart...
# 18  I initially booked two separate flights airlin...
# 19  I flew SQ217 Singapore Melbourne 4th January. ...
#
#                                             Reviews_4  \
# 0   flight amaz crew onboard flight welcom gave go...
# 1   book emerg exit seat still meant huge discomfo...
# 2   excel perform front would definit choos use ai...
# 3   pretti comfort flight consid fli economi class...
# 4   servic consist good start finish cabin crew sh...
# 5   flight six hour long b max book emerg exit row...
# 6   board process went smoothli plane left time wi...
# 7   pleasant flight oper time checkin changi smoot...
# 8   embark journey high hope anticip secur connect...
# 9   queue checkin board gate done orderli fashion ...
# 10  competit price rout servic reliabl friendli fl...
# 11  first time fli region singapor airlin flight n...
# 12  superb servic even economi class noth much tro...
# 13  one last busi class passeng board went seat of...
# 14  flight smooth sail problem whatsoev cabin crew...
# 15  flew perth hong kong via singapor sq busi clas...
# 16  final trip book juli singapor cancel return fl...
# 17  book wheelchair servic milan bangkok apart sli...
# 18  initi book two separ flight airlin novemb firs...
# 19  flew sq singapor melbourn th januari flight te...
#
#                                             Reviews_2  \
# 0   flight amazing crew onboard flight welcoming g...
# 1   booking emergency exit seat still meant huge d...
# 2   excellent performance fronts would definitely ...
# 3   pretty comfortable flight considering flying e...
# 4   service consistently good start finish cabin c...
# 5   flight six hours long b737 max8 booked emergen...
# 6   boarding process went smoothly plane left time...
# 7   pleasant flight operated time check changi smo...
# 8   embarked journey high hopes anticipation secur...
# 9   queue check boarding gate done orderly fashion...
# 10  competitive pricing route service reliable fri...
# 11  first time flying regional singapore airlines ...
# 12  superb service even economy class nothing much...
# 13  one last business class passengers board went ...
# 14  flight smooth sailing problems whatsoever cabi...
# 15  flew perth hong kong via singapore sq226 896 b...
# 16  final trip booked july 2024 singapore cancelle...
# 17  booked wheelchair service milan bangkok apart ...
# 18  initially booked two separate flights airline ...
# 19  flew sq217 singapore melbourne 4th january fli...
#
#                                             Reviews_5
# 0   [[1.7306, 0.284, -0.040613, -0.087372, -0.4819...
# 1   [[0.75874, -0.22013, -0.12103, 0.021208, -0.65...
# 2   [[-0.40431, 0.78002, -0.67538, -0.097149, 0.54...
# 3   [[-0.24922, -0.39835, -0.45851, -0.34846, 0.74...
# 4   [[0.418, 0.24968, -0.41242, 0.1217, 0.34527, -...
# 5   [[0.53074, 0.40117, -0.40785, 0.15444, 0.47782...
# 6   [[0.47061, 0.38608, -0.38143, -1.628, -0.16672...
# 7   [[0.4512, 1.315, -1.0892, -0.33892, 0.43551, -...
# 8   [[0.11891, 0.15255, -0.082073, -0.74144, 0.759...
# 9   [[0.34957, 0.40147, -0.012561, 0.13743, 0.4008...
# 10  [[-0.81014, -0.28234, -0.28727, 0.6359, -0.273...
# 11  [[0.53074, 0.40117, -0.40785, 0.15444, 0.47782...
# 12  [[-0.48425, -0.11201, -0.84138, -0.27306, 0.42...
# 13  [[0.11891, 0.15255, -0.082073, -0.74144, 0.759...
# 14  [[0.418, 0.24968, -0.41242, 0.1217, 0.34527, -...
# 15  [[0.11891, 0.15255, -0.082073, -0.74144, 0.759...
# 16  [[0.15272, 0.36181, -0.22168, 0.066051, 0.1302...
# 17  [[0.65464, -0.4608, -0.031696, 0.33362, -0.141...
# 18  [[0.11891, 0.15255, -0.082073, -0.74144, 0.759...
# 19  [[0.11891, 0.15255, -0.082073, -0.74144, 0.759...

# %%
## Using Dataset wrapper
tokenized_embedded_reviews = dataset['Reviews_5']
reviews_labels = dataset['Sentiment']
reviews_dataset = ReviewsDataset(reviews=tokenized_embedded_reviews, labels=reviews_labels)

# %%
## Split dataset
train_set, val_set, test_set = torch.utils.data.random_split(
    reviews_dataset, [0.8, 0.1, 0.1], generator=torch.Generator().manual_seed(20)
)

# %%
## Create DataLoaders
train_loader = DataLoader(dataset=train_set, batch_size=BATCH_SIZE, shuffle=True, collate_fn=review_collate_fn)
val_loader = DataLoader(dataset=val_set, batch_size=BATCH_SIZE, shuffle=True, collate_fn=review_collate_fn)
test_loader = DataLoader(dataset=test_set, batch_size=BATCH_SIZE, shuffle=True, collate_fn=review_collate_fn)

# %%
## Check batches
example_features, example_label = next(iter(train_loader))
print(f'Sample feature: \n{example_features}, \nFeature size: {example_features.shape}')
print(f'Sample label: \n{example_label}')

## Assert that feature size is (batch_size, sequence_length ie review_length, feature_size ie word_vec_size)
assert example_features.shape == torch.Size([10, 200, 50]), 'Batch provided by DataLoader is of wrong size'
# Out:
# Sample feature:
# tensor([[[ 0.1527,  0.3618, -0.2217,  ...,  0.4338, -0.0846,  0.1214],
#          [-0.2728,  0.7752, -0.1018,  ..., -0.7337,  0.0404,  0.2666],
#          [-0.4124,  0.6493, -0.5585,  ...,  0.2621,  0.1045, -0.4430],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#         [[ 0.5307,  0.4012, -0.4078,  ...,  0.2876,  0.1444,  0.2361],
#          [ 1.7306,  0.2840, -0.0406,  ...,  0.3401, -0.0973,  0.2801],
#          [ 0.0869, -0.1942, -0.2427,  ..., -0.7700,  0.3945, -0.1694],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#         [[ 0.1189,  0.1525, -0.0821,  ..., -0.5751, -0.2667,  0.9212],
#          [ 0.9068, -0.0447,  0.4056,  ..., -0.3866, -0.8427, -0.2818],
#          [-0.4111,  0.4676, -1.0384,  ..., -0.3965,  0.4326, -0.6722],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#         ...,
#
#         [[ 0.5307,  0.4012, -0.4078,  ...,  0.2876,  0.1444,  0.2361],
#          [ 0.0869, -0.1942, -0.2427,  ..., -0.7700,  0.3945, -0.1694],
#          [-0.2728,  0.7752, -0.1018,  ..., -0.7337,  0.0404,  0.2666],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#         [[ 0.4512,  1.3150, -1.0892,  ..., -0.4872,  0.2498,  1.3152],
#          [ 1.7306,  0.2840, -0.0406,  ...,  0.3401, -0.0973,  0.2801],
#          [ 0.9056,  0.0540, -0.0241,  ..., -0.1291, -0.1832, -0.5880],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#         [[-0.4043,  0.7800, -0.6754,  ...,  0.7225,  0.4759,  0.7951],
#          [-0.5099,  0.2876, -0.4129,  ...,  0.3351,  0.1340,  1.0052],
#          [ 0.3004,  0.2501, -0.1669,  ..., -0.0713,  0.2305, -0.5194],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]]),
# Feature size: torch.Size([10, 200, 50])
# Sample label:
# tensor([0., 0., 2., 2., 2., 2., 2., 2., 2., 2.])

# %%
## Initialize an LSTM model
    ## Hyperparameters
embedding_dim = 50
hidden_dim = 64
num_lstm_layers = 1
cell_dropout = 0.1

model = SimpleLSTM(embedding_dim, hidden_dim, num_lstm_layers, cell_dropout)
print(model)
# Out:
# SimpleLSTM(
#   (model): ModuleDict(
#     (lstm): LSTM(50, 64, batch_first=True, dropout=0.1)
#     (linear1): Linear(in_features=64, out_features=3, bias=True)
#     (sigmoid): Sigmoid()
#   )
# )

# %%
## Test forward pass
example_output = model(example_features.to(DEVICE))
print(f'Sample output: \n{example_output}')
# Out:
# Sample output:
# (tensor([[0.4997, 0.5243, 0.5028],
#         [0.4997, 0.5243, 0.5028],
#         [0.4997, 0.5243, 0.5028],
#         [0.4997, 0.5243, 0.5028],
#         [0.4997, 0.5243, 0.5028],
#         [0.4997, 0.5243, 0.5028],
#         [0.4997, 0.5243, 0.5028],
#         [0.4997, 0.5243, 0.5028],
#         [0.4997, 0.5243, 0.5028],
#         [0.4997, 0.5243, 0.5028]], grad_fn=<SigmoidBackward0>), tensor([[-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587],
#         [-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587],
#         [-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587],
#         [-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587],
#         [-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587],
#         [-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587],
#         [-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587],
#         [-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587],
#         [-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587],
#         [-0.0282, -0.0089, -0.0667,  0.0447, -0.0328,  0.0650, -0.0334,  0.0322,
#          -0.0363, -0.0422, -0.0951, -0.0023,  0.0646,  0.0734, -0.0823, -0.0244,
#          -0.1229,  0.0260, -0.0238,  0.0861, -0.0334,  0.0769,  0.0700, -0.0005,
#          -0.0619,  0.0084,  0.0494,  0.0742,  0.0528, -0.0441,  0.1016,  0.0556,
#          -0.0189, -0.0870, -0.0028,  0.0984, -0.0087,  0.0847,  0.0134,  0.0034,
#          -0.0563,  0.0026,  0.0033, -0.0601, -0.0309, -0.0152,  0.0460,  0.0268,
#           0.0625,  0.0591, -0.0123,  0.0376, -0.0714,  0.0368, -0.0112,  0.0315,
#          -0.0720, -0.0727, -0.0908, -0.0060,  0.0473,  0.0752, -0.0734, -0.0587]],
#        grad_fn=<SelectBackward0>))

# %%
example_loss, example_f1 = evaluation(model, val_loader)
print(f'Loss: {example_loss}')
print(f'F1: {example_f1}')
# Out:
# Loss: 1.1048007011413574
# F1: 0.0

# %%
## Training the model
embedding_dim = 50
hidden_dim = 64
num_lstm_layers = 2
cell_dropout = 0.1

model = SimpleLSTM(embedding_dim, hidden_dim, num_lstm_layers, cell_dropout)

trained_model = train_model(model, train_loader, val_loader, lr=0.001, epochs=2)

## Save model
curr_datetime = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')
file_dir = '.experiments/'
file_name = f'model_{curr_datetime}.pt'
torch.save(model.state_dict(), file_dir + file_name)
# Out:
# ======== Epoch 1 ========
# Training loss: 1.0861	 Training F1: 0.1
# Validation loss: 1.0794	 Validation F1: 0.0
# ======== Epoch 2 ========
# Training loss: 1.0798	 Training F1: 0.39495798319327735
# Validation loss: 1.0690	 Validation F1: 1.0

# %%
## Hyperparameter tuning
param_grid = {
    'hidden_dim': [32, 64],
    'lstm_layers': [2, 3],
    'dropout': [0.1, 0.8]
}
embedding_dim = 50

models = []

for curr_hidden_dim in param_grid['hidden_dim']:
    for curr_num_lstm_layers in param_grid['lstm_layers']:
        for curr_dropout in param_grid['dropout']:
            text = f'hidden_dim: {curr_hidden_dim}, num_lstm_layers: {curr_num_lstm_layers}, dropout: {curr_dropout}'
            print(text)

            curr_model = SimpleLSTM(embedding_dim, curr_hidden_dim, curr_num_lstm_layers, curr_dropout)
            curr_trained_model = train_model(curr_model, train_loader, val_loader, lr=0.001, epochs=10)
            models.append((text, curr_trained_model))
# Out:
# hidden_dim: 32, num_lstm_layers: 2, dropout: 0.1
# ======== Epoch 1 ========
# Training loss: 1.0884	 Training F1: 0.5601851851851851
# Validation loss: 1.0733	 Validation F1: 1.0
# ======== Epoch 2 ========
# Training loss: 1.0837	 Training F1: 0.5601851851851851
# Validation loss: 1.0666	 Validation F1: 1.0
# ======== Epoch 3 ========
# Training loss: 1.0792	 Training F1: 0.5601851851851851
# Validation loss: 1.0599	 Validation F1: 1.0
# ======== Epoch 4 ========
# Training loss: 1.0751	 Training F1: 0.5601851851851851
# Validation loss: 1.0529	 Validation F1: 1.0
# ======== Epoch 5 ========
# Training loss: 1.0705	 Training F1: 0.5601851851851851
# Validation loss: 1.0455	 Validation F1: 1.0
# ======== Epoch 6 ========
# Training loss: 1.0674	 Training F1: 0.5601851851851851
# Validation loss: 1.0376	 Validation F1: 1.0
# ======== Epoch 7 ========
# Training loss: 1.0600	 Training F1: 0.5601851851851851
# Validation loss: 1.0291	 Validation F1: 1.0
# ======== Epoch 8 ========
# Training loss: 1.0505	 Training F1: 0.5601851851851851
# Validation loss: 1.0199	 Validation F1: 1.0
# ======== Epoch 9 ========
# Training loss: 1.0533	 Training F1: 0.5601851851851851
# Validation loss: 1.0095	 Validation F1: 1.0
# ======== Epoch 10 ========
# Training loss: 1.0438	 Training F1: 0.5601851851851851
# Validation loss: 0.9975	 Validation F1: 1.0
# hidden_dim: 32, num_lstm_layers: 2, dropout: 0.8
# ======== Epoch 1 ========
# Training loss: 1.0937	 Training F1: 0.4375
# Validation loss: 1.0786	 Validation F1: 1.0
# ======== Epoch 2 ========
# Training loss: 1.0950	 Training F1: 0.5601851851851851
# Validation loss: 1.0738	 Validation F1: 1.0
# ======== Epoch 3 ========
# Training loss: 1.0876	 Training F1: 0.5601851851851851
# Validation loss: 1.0691	 Validation F1: 1.0
# ======== Epoch 4 ========
# Training loss: 1.0838	 Training F1: 0.5601851851851851
# Validation loss: 1.0643	 Validation F1: 1.0
# ======== Epoch 5 ========
# Training loss: 1.0864	 Training F1: 0.5601851851851851
# Validation loss: 1.0593	 Validation F1: 1.0
# ======== Epoch 6 ========
# Training loss: 1.0828	 Training F1: 0.5601851851851851
# Validation loss: 1.0542	 Validation F1: 1.0
# ======== Epoch 7 ========
# Training loss: 1.0740	 Training F1: 0.5601851851851851
# Validation loss: 1.0488	 Validation F1: 1.0
# ======== Epoch 8 ========
# Training loss: 1.0751	 Training F1: 0.5601851851851851
# Validation loss: 1.0428	 Validation F1: 1.0
# ======== Epoch 9 ========
# Training loss: 1.0629	 Training F1: 0.5601851851851851
# Validation loss: 1.0361	 Validation F1: 1.0
# ======== Epoch 10 ========
# Training loss: 1.0648	 Training F1: 0.5601851851851851
# Validation loss: 1.0282	 Validation F1: 1.0
# hidden_dim: 32, num_lstm_layers: 3, dropout: 0.1
# ======== Epoch 1 ========
# Training loss: 1.0942	 Training F1: 0.5601851851851851
# Validation loss: 1.0808	 Validation F1: 1.0
# ======== Epoch 2 ========
# Training loss: 1.0876	 Training F1: 0.5601851851851851
# Validation loss: 1.0749	 Validation F1: 1.0
# ======== Epoch 3 ========
# Training loss: 1.0853	 Training F1: 0.5601851851851851
# Validation loss: 1.0684	 Validation F1: 1.0
# ======== Epoch 4 ========
# Training loss: 1.0829	 Training F1: 0.5601851851851851
# Validation loss: 1.0611	 Validation F1: 1.0
# ======== Epoch 5 ========
# Training loss: 1.0768	 Training F1: 0.5601851851851851
# Validation loss: 1.0528	 Validation F1: 1.0
# ======== Epoch 6 ========
# Training loss: 1.0773	 Training F1: 0.5601851851851851
# Validation loss: 1.0432	 Validation F1: 1.0
# ======== Epoch 7 ========
# Training loss: 1.0685	 Training F1: 0.5601851851851851
# Validation loss: 1.0319	 Validation F1: 1.0
# ======== Epoch 8 ========
# Training loss: 1.0619	 Training F1: 0.5601851851851851
# Validation loss: 1.0180	 Validation F1: 1.0
# ======== Epoch 9 ========
# Training loss: 1.0502	 Training F1: 0.5601851851851851
# Validation loss: 1.0008	 Validation F1: 1.0
# ======== Epoch 10 ========
# Training loss: 1.0507	 Training F1: 0.5601851851851851
# Validation loss: 0.9789	 Validation F1: 1.0
# hidden_dim: 32, num_lstm_layers: 3, dropout: 0.8
# ======== Epoch 1 ========
# Training loss: 1.1083	 Training F1: 0.007352941176470588
# Validation loss: 1.1053	 Validation F1: 0.0
# ======== Epoch 2 ========
# Training loss: 1.1035	 Training F1: 0.007352941176470588
# Validation loss: 1.0977	 Validation F1: 0.0
# ======== Epoch 3 ========
# Training loss: 1.0988	 Training F1: 0.20535714285714288
# Validation loss: 1.0898	 Validation F1: 1.0
# ======== Epoch 4 ========
# Training loss: 1.0959	 Training F1: 0.4375
# Validation loss: 1.0815	 Validation F1: 1.0
# ======== Epoch 5 ========
# Training loss: 1.0900	 Training F1: 0.49500000000000005
# Validation loss: 1.0731	 Validation F1: 1.0
# ======== Epoch 6 ========
# Training loss: 1.0888	 Training F1: 0.5601851851851851
# Validation loss: 1.0634	 Validation F1: 1.0
# ======== Epoch 7 ========
# Training loss: 1.0792	 Training F1: 0.5601851851851851
# Validation loss: 1.0529	 Validation F1: 1.0
# ======== Epoch 8 ========
# Training loss: 1.0685	 Training F1: 0.5601851851851851
# Validation loss: 1.0407	 Validation F1: 1.0
# ======== Epoch 9 ========
# Training loss: 1.0714	 Training F1: 0.5601851851851851
# Validation loss: 1.0261	 Validation F1: 1.0
# ======== Epoch 10 ========
# Training loss: 1.0582	 Training F1: 0.5601851851851851
# Validation loss: 1.0088	 Validation F1: 1.0
# hidden_dim: 64, num_lstm_layers: 2, dropout: 0.1
# ======== Epoch 1 ========
# Training loss: 1.0983	 Training F1: 0.007352941176470588
# Validation loss: 1.0885	 Validation F1: 1.0
# ======== Epoch 2 ========
# Training loss: 1.0929	 Training F1: 0.5817307692307692
# Validation loss: 1.0789	 Validation F1: 1.0
# ======== Epoch 3 ========
# Training loss: 1.0903	 Training F1: 0.6817307692307691
# Validation loss: 1.0687	 Validation F1: 1.0
# ======== Epoch 4 ========
# Training loss: 1.0780	 Training F1: 0.6817307692307691
# Validation loss: 1.0575	 Validation F1: 1.0
# ======== Epoch 5 ========
# Training loss: 1.0719	 Training F1: 0.6817307692307691
# Validation loss: 1.0430	 Validation F1: 1.0
# ======== Epoch 6 ========
# Training loss: 1.0661	 Training F1: 0.6817307692307691
# Validation loss: 1.0227	 Validation F1: 1.0
# ======== Epoch 7 ========
# Training loss: 1.0482	 Training F1: 0.6817307692307691
# Validation loss: 0.9930	 Validation F1: 1.0
# ======== Epoch 8 ========
# Training loss: 1.0282	 Training F1: 0.6817307692307691
# Validation loss: 0.9487	 Validation F1: 1.0
# ======== Epoch 9 ========
# Training loss: 1.0113	 Training F1: 0.6817307692307691
# Validation loss: 0.8875	 Validation F1: 1.0
# ======== Epoch 10 ========
# Training loss: 0.9857	 Training F1: 0.6817307692307691
# Validation loss: 0.8215	 Validation F1: 1.0
# hidden_dim: 64, num_lstm_layers: 2, dropout: 0.8
# ======== Epoch 1 ========
# Training loss: 1.1090	 Training F1: 0.1
# Validation loss: 1.1148	 Validation F1: 0.0
# ======== Epoch 2 ========
# Training loss: 1.1032	 Training F1: 0.1
# Validation loss: 1.1072	 Validation F1: 0.0
# ======== Epoch 3 ========
# Training loss: 1.0971	 Training F1: 0.1
# Validation loss: 1.0991	 Validation F1: 0.0
# ======== Epoch 4 ========
# Training loss: 1.0932	 Training F1: 0.1
# Validation loss: 1.0904	 Validation F1: 0.0
# ======== Epoch 5 ========
# Training loss: 1.0889	 Training F1: 0.1
# Validation loss: 1.0800	 Validation F1: 1.0
# ======== Epoch 6 ========
# Training loss: 1.0818	 Training F1: 0.7291666666666666
# Validation loss: 1.0668	 Validation F1: 1.0
# ======== Epoch 7 ========
# Training loss: 1.0753	 Training F1: 0.6817307692307691
# Validation loss: 1.0497	 Validation F1: 1.0
# ======== Epoch 8 ========
# Training loss: 1.0586	 Training F1: 0.6817307692307691
# Validation loss: 1.0258	 Validation F1: 1.0
# ======== Epoch 9 ========
# Training loss: 1.0381	 Training F1: 0.6817307692307691
# Validation loss: 0.9890	 Validation F1: 1.0
# ======== Epoch 10 ========
# Training loss: 1.0148	 Training F1: 0.6817307692307691
# Validation loss: 0.9283	 Validation F1: 1.0
# hidden_dim: 64, num_lstm_layers: 3, dropout: 0.1
# ======== Epoch 1 ========
# Training loss: 1.1150	 Training F1: 0.007352941176470588
# Validation loss: 1.1126	 Validation F1: 0.0
# ======== Epoch 2 ========
# Training loss: 1.1078	 Training F1: 0.007352941176470588
# Validation loss: 1.1018	 Validation F1: 0.0
# ======== Epoch 3 ========
# Training loss: 1.1020	 Training F1: 0.007352941176470588
# Validation loss: 1.0886	 Validation F1: 0.0
# ======== Epoch 4 ========
# Training loss: 1.0934	 Training F1: 0.3235294117647059
# Validation loss: 1.0718	 Validation F1: 1.0
# ======== Epoch 5 ========
# Training loss: 1.0830	 Training F1: 0.5601851851851851
# Validation loss: 1.0479	 Validation F1: 1.0
# ======== Epoch 6 ========
# Training loss: 1.0729	 Training F1: 0.5601851851851851
# Validation loss: 1.0133	 Validation F1: 1.0
# ======== Epoch 7 ========
# Training loss: 1.0461	 Training F1: 0.5601851851851851
# Validation loss: 0.9600	 Validation F1: 1.0
# ======== Epoch 8 ========
# Training loss: 1.0046	 Training F1: 0.5601851851851851
# Validation loss: 0.8829	 Validation F1: 1.0
# ======== Epoch 9 ========
# Training loss: 0.9704	 Training F1: 0.5601851851851851
# Validation loss: 0.8007	 Validation F1: 1.0
# ======== Epoch 10 ========
# Training loss: 0.9362	 Training F1: 0.5601851851851851
# Validation loss: 0.7410	 Validation F1: 1.0
# hidden_dim: 64, num_lstm_layers: 3, dropout: 0.8
# ======== Epoch 1 ========
# Training loss: 1.0789	 Training F1: 0.5601851851851851
# Validation loss: 1.0645	 Validation F1: 1.0
# ======== Epoch 2 ========
# Training loss: 1.0769	 Training F1: 0.5601851851851851
# Validation loss: 1.0533	 Validation F1: 1.0
# ======== Epoch 3 ========
# Training loss: 1.0683	 Training F1: 0.5601851851851851
# Validation loss: 1.0413	 Validation F1: 1.0
# ======== Epoch 4 ========
# Training loss: 1.0585	 Training F1: 0.5601851851851851
# Validation loss: 1.0266	 Validation F1: 1.0
# ======== Epoch 5 ========
# Training loss: 1.0588	 Training F1: 0.5601851851851851
# Validation loss: 1.0079	 Validation F1: 1.0
# ======== Epoch 6 ========
# Training loss: 1.0470	 Training F1: 0.5601851851851851
# Validation loss: 0.9830	 Validation F1: 1.0
# ======== Epoch 7 ========
# Training loss: 1.0321	 Training F1: 0.5601851851851851
# Validation loss: 0.9462	 Validation F1: 1.0
# ======== Epoch 8 ========
# Training loss: 1.0075	 Training F1: 0.5601851851851851
# Validation loss: 0.8917	 Validation F1: 1.0
# ======== Epoch 9 ========
# Training loss: 1.0086	 Training F1: 0.5601851851851851
# Validation loss: 0.8281	 Validation F1: 1.0
# ======== Epoch 10 ========
# Training loss: 0.9528	 Training F1: 0.5601851851851851
# Validation loss: 0.7681	 Validation F1: 1.0

# %%
## Train model again with best hyperparameters
embedding_dim = 50
hidden_dim = 64
num_lstm_layers = 2
cell_dropout = 0.8

best_model = SimpleLSTM(embedding_dim, hidden_dim, num_lstm_layers, cell_dropout)

## Initialize early stopper
curr_datetime = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')
file_dir = '.experiments/tuned/'
file_name = f'model_{curr_datetime}.pt'

early_stopper = EarlyStopper(patience=3, delta=0.005, path=file_dir+file_name)

## Train model, stopping when no further improvements
best_model = train_model(best_model, train_loader, val_loader, lr=0.001, epochs=100, early_stopper=early_stopper)
# Out:
# ======== Epoch 1 ========
# Training loss: 1.1085	 Training F1: 0.008333333333333333
# Validation loss: 1.1109	 Validation F1: 0.0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[55], line 17
#      14 early_stopper = EarlyStopper(patience=3, delta=0.005, path=file_dir+file_name)
#      16 ## Train model, stopping when no further improvements
# ---> 17 best_model = train_model(best_model, train_loader, val_loader, lr=0.001, epochs=100, early_stopper=early_stopper)
#
# File ~/MannheimWMProject/zm_lstm_helper.py:206, in train_model(model, train_loader, val_loader, lr, epochs, loss_fn, early_stopper, device)
#     204 ## If necessary, check early stopping criteria
#     205 if early_stopper != None:
# --> 206     early_stopper(model, val_loss / len(val_loader))
#     207     if early_stopper.early_stop:
#     208         break
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/MannheimWMProject/zm_lstm_helper.py:132, in EarlyStopper.__call__(self, model, val_loss)
#     130 if self.best_loss == None:
#     131     self.best_loss = val_loss
# --> 132     torch.save(model.state_dict(), self.path)
#     133     print(f'Initialize baseline model, loss: {val_loss}')
#     134 ## If val loss deteriorates by a certain degree, exhaust patience
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/serialization.py:628, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     625 _check_save_filelike(f)
#     627 if _use_new_zipfile_serialization:
# --> 628     with _open_zipfile_writer(f) as opened_zipfile:
#     629         _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#     630         return
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/serialization.py:502, in _open_zipfile_writer(name_or_buffer)
#     500 else:
#     501     container = _open_zipfile_writer_buffer
# --> 502 return container(name_or_buffer)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/serialization.py:473, in _open_zipfile_writer_file.__init__(self, name)
#     471     super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     472 else:
# --> 473     super().__init__(torch._C.PyTorchFileWriter(self.name))
#
# RuntimeError: Parent directory .experiments/tuned does not exist.

# %%
## Evaluate model performance on test set
best_model = SimpleLSTM(embedding_dim=50, hidden_dim=64, num_lstm_layers=2, cell_dropout=0.1).to(DEVICE)
best_model.load_state_dict(torch.load('.experiments\lstm_trained_model.pt'))

test_loss, test_f1 = evaluation(best_model, test_loader)
print(f'Test loss: {test_loss / len(test_loader):.4f}\t', f'Test F1: {test_f1}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 3
#       1 ## Evaluate model performance on test set
#       2 best_model = SimpleLSTM(embedding_dim=50, hidden_dim=64, num_lstm_layers=2, cell_dropout=0.1).to(DEVICE)
# ----> 3 best_model.load_state_dict(torch.load('.experiments\lstm_trained_model.pt'))
#       5 test_loss, test_f1 = evaluation(best_model, test_loader)
#       6 print(f'Test loss: {test_loss / len(test_loader):.4f}\t', f'Test F1: {test_f1}')
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995 if 'encoding' not in pickle_load_args.keys():
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
#    1002         # reset back to the original position.
#    1003         orig_position = opened_file.tell()
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/serialization.py:445, in _open_file_like(name_or_buffer, mode)
#     443 def _open_file_like(name_or_buffer, mode):
#     444     if _is_path(name_or_buffer):
# --> 445         return _open_file(name_or_buffer, mode)
#     446     else:
#     447         if 'w' in mode:
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/serialization.py:426, in _open_file.__init__(self, name, mode)
#     425 def __init__(self, name, mode):
# --> 426     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '.experiments\\lstm_trained_model.pt'

# %%
## Retrieving the performance scores for each class
all_pred_class = []
all_labels = []

for reviews, labels in test_loader:
    reviews, labels = reviews.to(DEVICE), labels.to(DEVICE)

    ## Forward pass
    pred, thought_vector = best_model(reviews)
    pred_class = torch.argmax(pred, dim=1).to('cpu')

    all_pred_class.extend(pred_class.numpy())
    all_labels.extend(labels.to('cpu').numpy())

assert len(all_pred_class) == len(all_labels)
