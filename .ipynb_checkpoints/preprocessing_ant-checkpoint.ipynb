# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Vader" data-toc-modified-id="Vader-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Vader</a></span></li><li><span><a href="#Text-Blob" data-toc-modified-id="Text-Blob-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Text Blob</a></span></li></ul></div>

# %% [markdown]
# # Libraries

# %%
import pandas as pd

import functions

import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Data

# %%
data = pd.read_csv('/Users/antoniooliveira/Downloads/airlines_reviews.csv')

# %%
data.head()
# Out:
#                                   Title              Name Review Date  \
# 0                    Flight was amazing  Alison Soetantyo  2024-03-01
# 1  seats on this aircraft are dreadful      Robert Watson  2024-02-21
# 2          Food was plentiful and tasty             S Han  2024-02-20
# 3          “how much food was available          D Laynes  2024-02-19
# 4       “service was consistently good”         A Othman   2024-02-19
#
#               Airline Verified  \
# 0  Singapore Airlines     True
# 1  Singapore Airlines     True
# 2  Singapore Airlines     True
# 3  Singapore Airlines     True
# 4  Singapore Airlines     True
#
#                                              Reviews Type of Traveller  \
# 0    Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1    Booking an emergency exit seat still meant h...      Solo Leisure
# 2    Excellent performance on all fronts. I would...    Family Leisure
# 3   Pretty comfortable flight considering I was f...      Solo Leisure
# 4   The service was consistently good from start ...    Family Leisure
#
#      Month Flown                         Route           Class  Seat Comfort  \
# 0  December 2023          Jakarta to Singapore  Business Class             4
# 1  February 2024           Phuket to Singapore   Economy Class             5
# 2  February 2024        Siem Reap to Singapore   Economy Class             1
# 3  February 2024  Singapore to London Heathrow   Economy Class             5
# 4  February 2024       Singapore to Phnom Penh   Economy Class             5
#
#    Staff Service  Food & Beverages  Inflight Entertainment  Value For Money  \
# 0              4                 4                       4                4
# 1              3                 4                       4                1
# 2              5                 2                       1                5
# 3              5                 5                       5                5
# 4              5                 5                       5                5
#
#    Overall Rating Recommended
# 0               9         yes
# 1               3          no
# 2              10         yes
# 3              10         yes
# 4              10         yes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8100 entries, 0 to 8099
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   8100 non-null   object
#  1   Name                    8100 non-null   object
#  2   Review Date             8100 non-null   object
#  3   Airline                 8100 non-null   object
#  4   Verified                8100 non-null   object
#  5   Reviews                 8100 non-null   object
#  6   Type of Traveller       8100 non-null   object
#  7   Month Flown             8100 non-null   object
#  8   Route                   8100 non-null   object
#  9   Class                   8100 non-null   object
#  10  Seat Comfort            8100 non-null   int64
#  11  Staff Service           8100 non-null   int64
#  12  Food & Beverages        8100 non-null   int64
#  13  Inflight Entertainment  8100 non-null   int64
#  14  Value For Money         8100 non-null   int64
#  15  Overall Rating          8100 non-null   int64
#  16  Recommended             8100 non-null   object
# dtypes: int64(6), object(11)
# memory usage: 1.1+ MB

# %%
data.describe().T
# Out:
#                          count      mean       std  min  25%  50%  75%   max
# Seat Comfort            8100.0  3.414815  1.397183  1.0  2.0  4.0  5.0   5.0
# Staff Service           8100.0  3.569877  1.527436  1.0  2.0  4.0  5.0   5.0
# Food & Beverages        8100.0  3.384074  1.455694  1.0  2.0  4.0  5.0   5.0
# Inflight Entertainment  8100.0  3.636790  1.309564  0.0  3.0  4.0  5.0   5.0
# Value For Money         8100.0  3.148642  1.589377  1.0  1.0  3.0  5.0   5.0
# Overall Rating          8100.0  5.632469  3.523664  1.0  2.0  6.0  9.0  10.0

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Unique Values

# %%
for column in data.columns:
    print(data[column].value_counts(), '\n')
# Out:
# Title
# Turkish Airlines customer review    11
# Qatar Airways customer review       11
# worst customer service               9
# a pleasant experience                9
# seats were comfortable               8
#                                     ..
# very comfortable experience          1
# not impressed by the performance     1
# ANA is simply the best               1
# bad communication                    1
# genuinely friendly staff             1
# Name: count, Length: 7614, dtype: int64
#
# Name
# Michael Schade        44
# Anders Pedersen       40
# Michel Perrin         29
# Alwaleed Althani      27
# Elaine Loh            23
#                       ..
# G Deene                1
# G Hayes                1
# Jacob Chundamannil     1
# Ann Sebastian          1
# D Lanor                1
# Name: count, Length: 6583, dtype: int64
#
# Review Date
# 2017-12-18    12
# 2018-10-17    11
# 2019-10-16    11
# 2018-09-18    11
# 2019-09-22    11
#               ..
# 2019-09-10     1
# 2018-12-26     1
# 2018-04-17     1
# 2017-06-23     1
# 2024-03-01     1
# Name: count, Length: 2549, dtype: int64
#
# Airline
# Turkish Airlines          1685
# Qatar Airways             1624
# Emirates                  1350
# Singapore Airlines         972
# Air France                 798
# Cathay Pacific Airways     744
# EVA Air                    281
# All Nippon Airways         258
# Japan Airlines             201
# Korean Air                 187
# Name: count, dtype: int64
#
# Verified
# True                                                                                                                                                                                                                                           6216
# False                                                                                                                                                                                                                                          1881
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
#   Perth to Fukuoka via Tokyo. I would like to convey my deepest gratitude to the ANA ground staff/ supervisors in the check in desk areas at Perth International Airport. Before I could check in, I realised that I had accidentally left my mobile phone inside the car that dropped me off and I had no way of contacting them to retrieve my phone. In my distress, I turned to the first airport staff I met and they happened to be the ANA check-in supervisors. I had asked them on what I should do, whether I should check in first or try to retrieve my phone. Instead of providing me a textbook answer or redirecting me to the airport information desk, she offered for me to use her own mobile phone to call my family. I was shocked and deeply grateful. I had to make multiple calls on multiple phone numbers. But she remained She even continued to help me call my family as I checked in. They were patient, calm, and immensely helpful. In the end, I was able to retrieve my mobile phone. I am so grateful for the superb customer service. This is true service, serving with their hearts. 110% recommend. Will definitely fly ANA again!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
#   The 13 hour flight in Business class from Seoul to Toronto onboard Korean Air KE73 turned out to be a real pleasure. Overall, there was a good choice of food, drinks (including Canadian ice wine) and the service was provided by genuinely friendly staff. Definitely recommended.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Name: count, Length: 8099, dtype: int64
#
# Type of Traveller
# Solo Leisure      3237
# Couple Leisure    1899
# Family Leisure    1551
# Business          1413
# Name: count, dtype: int64
#
# Month Flown
# November 2017    150
# December 2019    142
# January 2019     138
# December 2017    136
# November 2019    135
#                 ...
# March 2024         3
# May 2014           1
# March 2013         1
# April 2013         1
# May 2015           1
# Name: count, Length: 107, dtype: int64
#
# Route
# Bangkok to Hong Kong                  24
# London to Singapore                   23
# Istanbul to London                    20
# Bangkok to Singapore                  20
# Hong Kong to Singapore                19
#                                       ..
# Amsterdam to Cebu via Dubai            1
# Ho Chi Minh to Frankfurt via Dubai     1
# Sydney to Moscow via Dubai             1
# Brisbane to Madrid via Dubai           1
# ICN to YYZ                             1
# Name: count, Length: 5566, dtype: int64
#
# Class
# Economy Class      5504
# Business Class     2104
# Premium Economy     371
# First Class         121
# Name: count, dtype: int64
#
# Seat Comfort
# 5    2332
# 4    2072
# 3    1534
# 1    1214
# 2     948
# Name: count, dtype: int64
#
# Staff Service
# 5    3415
# 1    1414
# 4    1412
# 3    1061
# 2     798
# Name: count, dtype: int64
#
# Food & Beverages
# 5    2541
# 4    1743
# 3    1470
# 1    1368
# 2     978
# Name: count, dtype: int64
#
# Inflight Entertainment
# 5    2672
# 4    2284
# 3    1539
# 1     863
# 2     741
# 0       1
# Name: count, dtype: int64
#
# Value For Money
# 5    2427
# 1    2127
# 4    1513
# 3    1124
# 2     909
# Name: count, dtype: int64
#
# Overall Rating
# 1     1808
# 10    1610
# 9     1054
# 8      742
# 2      692
# 3      522
# 7      509
# 5      436
# 4      381
# 6      346
# Name: count, dtype: int64
#
# Recommended
# yes    4287
# no     3813
# Name: count, dtype: int64

# %% [markdown]
# Missing Values

# %%
data.isnull().sum()
# Out:
# Title                     0
# Name                      0
# Review Date               0
# Airline                   0
# Verified                  0
# Reviews                   0
# Type of Traveller         0
# Month Flown               0
# Route                     0
# Class                     0
# Seat Comfort              0
# Staff Service             0
# Food & Beverages          0
# Inflight Entertainment    0
# Value For Money           0
# Overall Rating            0
# Recommended               0
# dtype: int64

# %% [markdown]
# Checking for Incoherencies

# %%
data.sort_values(by='Review Date', ascending=False)
# Out:
#                                         Title           Name Review Date  \
# 2596    business seating is very comfortable     Susan James  2024-03-06
# 4405            don't waste money on Business       S Dunlop  2024-03-04
# 2854          certainly not a premium airline     E Galetski  2024-03-04
# 2855  Qatar Airways really puts them to shame        E Bayaz  2024-03-04
# 4406       cabin crew they seemed indifferent       S Dunlop  2024-03-04
# ...                                       ...            ...         ...
# 967                 a beautiful looking plane     Fiona Teo   2016-03-24
# 969                    crew were very relaxed   S Gooneratne  2016-03-23
# 6089            probably never fly them again  Mona Farrugia  2016-03-23
# 970                      Food and IFE average   S Gooneratne  2016-03-22
# 971               overall an enjoyable flight  Yeo Wei Sheng  2016-03-22
#
#                  Airline Verified  \
# 2596  All Nippon Airways    False
# 4405    Turkish Airlines     True
# 2854            Emirates     True
# 2855            Emirates     True
# 4406    Turkish Airlines     True
# ...                  ...      ...
# 967   Singapore Airlines    False
# 969   Singapore Airlines    False
# 6089    Turkish Airlines    False
# 970   Singapore Airlines     True
# 971   Singapore Airlines    False
#
#                                                 Reviews Type of Traveller  \
# 2596    ANA has great service, very clean restrooms ...    Couple Leisure
# 4405    Do not waste money on a Business Class fligh...          Business
# 2854    Our BKK-DXB flight was delayed for 18 hours ...    Family Leisure
# 2855    Definitely not the standard I would expect f...      Solo Leisure
# 4406    The plane was antiquated, my footrest box un...          Business
# ...                                                 ...               ...
# 967     Flew economy on Singapore to Kuala Lumpur re...          Business
# 969     Dhaka to Melbourne via Singapore, flights op...          Business
# 6089    Malta to Kilimanjaro via Dar es Salaam. We a...    Couple Leisure
# 970     Melbourne to Delhi via Singapore. Check in f...          Business
# 971     A very pleasant journey on Singapore Airline...      Solo Leisure
#
#         Month Flown                                 Route           Class  \
# 2596     March 2024             Ho Chi Minh City to Tokyo  Business Class
# 4405  February 2024  Manchester to Kathmandu via Istanbul  Business Class
# 2854  February 2024           Bangkok to Warsaw via Dubai   Economy Class
# 2855     March 2024   London Stansted to Lahore via Dubai  Business Class
# 4406   January 2024                    Bogota to Istanbul  Business Class
# ...             ...                                   ...             ...
# 967      March 2016                            MNL to SIN   Economy Class
# 969      March 2016                    MEL to DEL via SIN   Economy Class
# 6089     March 2016                            IAH to KHI  Business Class
# 970      March 2016                            SIN to CAN   Economy Class
# 971   December 2015                    KUL to SYD via SIN   Economy Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 2596             4              5                 4                       4
# 4405             3              3                 3                       3
# 2854             3              1                 3                       4
# 2855             4              3                 1                       1
# 4406             4              1                 1                       1
# ...            ...            ...               ...                     ...
# 967              2              5                 5                       4
# 969              5              5                 3                       4
# 6089             4              5                 3                       5
# 970              3              5                 4                       4
# 971              5              5                 5                       4
#
#       Value For Money  Overall Rating Recommended
# 2596                5              10         yes
# 4405                1               3          no
# 2854                1               1          no
# 2855                2               3          no
# 4406                2               3          no
# ...               ...             ...         ...
# 967                 2               8         yes
# 969                 4               9         yes
# 6089                2               2          no
# 970                 4               6         yes
# 971                 4               7         yes
#
# [8100 rows x 17 columns]

# %%
#Create new function to convert Rating scores to 3 categories
#1-3, 4-7, 8-10 forms negative, neutral, positive [0,1,2]
def score_convert_senti(score):
    if score <= 3:
        return 0
    elif score >= 4 and score <= 7:
        return 1
    elif score >= 8:
        return 2

#Create new column, convert scoring into 3 categories
data["Sentiment"] = data["Overall Rating"].apply(score_convert_senti)

#dataset has derived sentiment column added
data.head()
# Out:
#                                   Title              Name Review Date  \
# 0                    Flight was amazing  Alison Soetantyo  2024-03-01
# 1  seats on this aircraft are dreadful      Robert Watson  2024-02-21
# 2          Food was plentiful and tasty             S Han  2024-02-20
# 3          “how much food was available          D Laynes  2024-02-19
# 4       “service was consistently good”         A Othman   2024-02-19
#
#               Airline Verified  \
# 0  Singapore Airlines     True
# 1  Singapore Airlines     True
# 2  Singapore Airlines     True
# 3  Singapore Airlines     True
# 4  Singapore Airlines     True
#
#                                              Reviews Type of Traveller  \
# 0    Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1    Booking an emergency exit seat still meant h...      Solo Leisure
# 2    Excellent performance on all fronts. I would...    Family Leisure
# 3   Pretty comfortable flight considering I was f...      Solo Leisure
# 4   The service was consistently good from start ...    Family Leisure
#
#      Month Flown                         Route           Class  Seat Comfort  \
# 0  December 2023          Jakarta to Singapore  Business Class             4
# 1  February 2024           Phuket to Singapore   Economy Class             5
# 2  February 2024        Siem Reap to Singapore   Economy Class             1
# 3  February 2024  Singapore to London Heathrow   Economy Class             5
# 4  February 2024       Singapore to Phnom Penh   Economy Class             5
#
#    Staff Service  Food & Beverages  Inflight Entertainment  Value For Money  \
# 0              4                 4                       4                4
# 1              3                 4                       4                1
# 2              5                 2                       1                5
# 3              5                 5                       5                5
# 4              5                 5                       5                5
#
#    Overall Rating Recommended  Sentiment
# 0               9         yes          2
# 1               3          no          0
# 2              10         yes          2
# 3              10         yes          2
# 4              10         yes          2

# %% [markdown]
# # Preprocessing for Lexicon-based

# %%
# %pip install emoji
# Out:
# Requirement already satisfied: emoji in /opt/anaconda3/lib/python3.11/site-packages (2.11.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import regex as re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

import regex as re
import unicodedata
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
lemmatizer = WordNetLemmatizer()
from nltk.corpus import stopwords
from textblob import TextBlob
import emoji


def stopword_remover(tokenized_comment, stop_words):
    clean_comment = []
    for token in tokenized_comment:
        if token not in stop_words:
            clean_comment.append(token)
    return clean_comment

def preprocessor(raw_text, 
                 lowercase=True, 
                 leave_punctuation=False, 
                 remove_stopwords=True,
                 stop_words=None,
                 correct_spelling=False, 
                 lemmatization=False, 
                 porter_stemming=False,
                 tokenized_output=False, 
                 sentence_output=False,
                 remove_emojis = False
                 ):
    
    clean_text = raw_text

    if lowercase:
        if any(ord(char) > 127 for char in clean_text):
            clean_text = ''.join([unicodedata.normalize('NFKD', char).lower() for char in clean_text])
        else:
            clean_text = clean_text.lower()

    clean_text = re.sub(r'(\**\\[nrt]|</ul>)',' ',clean_text) 
    
    if not leave_punctuation:    
        clean_text = re.compile(r'[^\w\s]').sub(' ', clean_text)
    
    clean_text = re.sub(r'(\bhttp[^\s]+\b)',' ',clean_text)
    clean_text = re.sub(r'\b([^aeiou-])\b',' ',clean_text)

    if correct_spelling:
        incorrect_text = TextBlob(clean_text)
        clean_text = incorrect_text.correct()
        
    clean_text = word_tokenize(str(clean_text))
    
    if remove_stopwords:
        clean_text = stopword_remover(clean_text, stop_words)
        
    if lemmatization:
        for pos_tag in ["v","n","a"]:
            clean_text = [lemmatizer.lemmatize(token, pos=pos_tag) for token in clean_text]
    elif porter_stemming:  
        porter_stemmer = PorterStemmer()
        clean_text = [porter_stemmer.stem(token) for token in clean_text]
    
    if not tokenized_output:
        clean_text = " ".join(clean_text)
        clean_text = re.sub(r'(\s)(?!\w)','',clean_text)

    if sentence_output:
        clean_text = sent_tokenizer.tokenize(str(clean_text))
    
    # Adding emoji check
    if remove_emojis:  # Check if removing emojis is requested
        clean_text = emoji.demojize(clean_text)  # Convert emojis to text

    return clean_text
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data['Reviews_1'] = data['Reviews'].apply(lambda text: preprocessor(text,
                 lowercase=False, 
                 leave_punctuation = True, 
                 remove_stopwords = True,
                 stop_words = stop_words,
                 correct_spelling = False, 
                 lemmatization=False, 
                 porter_stemming=True,
                 tokenized_output=False, 
                 sentence_output=False,
                 remove_emojis=True))

# %%
data['Reviews_1'].sample()
# Out:
# 7232    melbourn lo angel via hong kong. hope never ge...
# Name: Reviews_1, dtype: object

# %% [markdown]
# ## Vader

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
vader = SentimentIntensityAnalyzer()

# %%
def vader_sa(song, compound = True):

    # Get the polarity scores (negative, neutral and positive) for the song
    polarity_scores_ = vader.polarity_scores(song)
    
    # If you want to compound the scores into one final score
    if compound:
        polarity = polarity_scores_["compound"]

    # If you want the three scores
    else:
        # The three separated scores
        polarity = polarity_scores_

    return polarity

# %%
data["vader_polarity_compound"] = data["Reviews_1"].apply(lambda song : vader_sa(str(song)))

data["vader_polarity_scores"] = data["Reviews_1"].apply(lambda song : vader_sa(str(song), compound = False))

# %%
data.sample(5)
# Out:
#                                 Title       Name Review Date  \
# 3102            our worst flight ever     D Dane  2022-01-29
# 8072         exceptionally good value  D Larassa  2017-01-24
# 7710  pointed to where to get luggage  G Carleno  2019-12-08
# 3134  25 hours sitting in the airport     N Zaid  2021-09-03
# 148              It was a 5/10 flight    N Beale  2022-12-28
#
#                  Airline Verified  \
# 3102            Emirates     True
# 8072          Korean Air    False
# 7710             EVA Air     True
# 3134            Emirates     True
# 148   Singapore Airlines     True
#
#                                                 Reviews Type of Traveller  \
# 3102    My family was flying from Male to Dubai and ...    Family Leisure
# 8072    Auckland to London via Seoul. Excellent comm...    Couple Leisure
# 7710    Tokyo to San Francisco via Taipei. EVA needs...      Solo Leisure
# 3134    First and hugest disappointment and shock ha...    Family Leisure
# 148     The flight seemed quite full with huge line ...    Couple Leisure
#
#         Month Flown                                Route            Class  \
# 3102   January 2022                     Chicago to Dubai    Economy Class
# 8072   January 2017         Auckland to London via Seoul   Business Class
# 7710  November 2019    Tokyo to San Francisco via Taipei  Premium Economy
# 3134    August 2021  Beirut to Dallas Ft Worth via Dubai    Economy Class
# 148   December 2022        Singapore to Ho Chi Minh City   Business Class
#
#       ...  Food & Beverages  Inflight Entertainment  Value For Money  \
# 3102  ...                 1                       2                2
# 8072  ...                 4                       5                5
# 7710  ...                 4                       3                5
# 3134  ...                 3                       3                3
# 148   ...                 2                       4                2
#
#       Overall Rating  Recommended  Sentiment  \
# 3102               2           no          0
# 8072              10          yes          2
# 7710               8          yes          2
# 3134               1           no          0
# 148                5           no          1
#
#                                               Reviews_1  \
# 3102  my famili fli male dubai worst flight ever. at...
# 8072  auckland london via seoul. excel commun advis ...
# 7710  tokyo san francisco via taipei. eva need under...
# 3134  first hugest disappoint shock happen open appl...
# 148   the flight seem quit full huge line gate secur...
#
#       vader_polarity_compound  \
# 3102                   0.8910
# 8072                   0.9670
# 7710                   0.9325
# 3134                  -0.9015
# 148                    0.4215
#
#                                   vader_polarity_scores  \
# 3102  {'neg': 0.045, 'neu': 0.763, 'pos': 0.193, 'co...
# 8072  {'neg': 0.028, 'neu': 0.684, 'pos': 0.288, 'co...
# 7710  {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'comp...
# 3134  {'neg': 0.126, 'neu': 0.847, 'pos': 0.027, 'co...
# 148   {'neg': 0.147, 'neu': 0.697, 'pos': 0.156, 'co...
#
#       textblob_polarity_compound
# 3102                   -0.050000
# 8072                    0.539286
# 7710                    0.130357
# 3134                    0.062905
# 148                     0.250441
#
# [5 rows x 22 columns]

# %%
data.groupby('Sentiment')['vader_polarity_compound'].describe()
# Out:
#             count      mean       std     min     25%      50%     75%     max
# Sentiment
# 0          3022.0 -0.129558  0.650024 -0.9914 -0.7430 -0.27320  0.4939  0.9944
# 1          1672.0  0.422056  0.588594 -0.9868  0.0258  0.68080  0.9022  0.9938
# 2          3406.0  0.802642  0.293201 -0.9300  0.7906  0.91255  0.9571  0.9984

# %%
data.loc[(data['vader_polarity_compound'] > 0.5) & (data['Sentiment'] == 0)]
# Out:
#                                        Title             Name Review Date  \
# 13    regional seat was really uncomfortable            L Hee  2024-02-16
# 19           not fly with them in the future          H Paran  2024-01-18
# 25              Deficient reservation system   Pierre Visseur  2023-12-27
# 30        “No inflight entertainment at all”        Ming Teoh  2023-12-11
# 36            Never again Singapore Airlines      Vibor Cilic  2023-11-18
# ...                                      ...              ...         ...
# 8039         flight attendants were terrible        S Chanson  2017-12-09
# 8048           totally unacceptable service   Nicholas Hurley  2017-09-20
# 8061           never take Korean Air anymore           Y Peck  2017-05-13
# 8078                my last flight with them        Julia Lee  2016-12-13
# 8085                 the worst Asian airline         G Nazano  2016-09-21
#
#                  Airline Verified  \
# 13    Singapore Airlines     True
# 19    Singapore Airlines     True
# 25    Singapore Airlines    False
# 30    Singapore Airlines    False
# 36    Singapore Airlines     True
# ...                  ...      ...
# 8039          Korean Air     True
# 8048          Korean Air     True
# 8061          Korean Air    False
# 8078          Korean Air     True
# 8085          Korean Air     True
#
#                                                 Reviews Type of Traveller  \
# 13      I was one of the last business class passeng...      Solo Leisure
# 19      I flew on SQ217 from Singapore to Melbourne ...    Couple Leisure
# 25      We made a Phuket-Singapore round trip which ...          Business
# 30      No inflight entertainment at all. Yes, we ar...      Solo Leisure
# 36     We had the most horrific check-in experience ...    Family Leisure
# ...                                                 ...               ...
# 8039    Bangkok to Atlanta via Seoul. My husband boo...      Solo Leisure
# 8048    Seoul to Hanoi. I wish to register my absolu...          Business
# 8061    Singapore to Seoul return. I will never take...    Family Leisure
# 8078    Hong Kong to Nadi, Fiji via Seoul. It was my...      Solo Leisure
# 8085    New York JFK to Tashkent via Seoul Incheon. ...          Business
#
#          Month Flown                         Route           Class  ...  \
# 13      January 2024     Singapore to Tokyo Haneda  Business Class  ...
# 19      January 2024        Singapore to Melbourne   Economy Class  ...
# 25     December 2023           Phuket to Singapore  Business Class  ...
# 30     December 2023           Singapore to Penang   Economy Class  ...
# 36     November 2023         New York to Frankfurt   Economy Class  ...
# ...              ...                           ...             ...  ...
# 8039   December 2017  Bangkok to Atlanta via Seoul  Business Class  ...
# 8048  September 2017                Seoul to Hanoi   Economy Class  ...
# 8061        May 2017            Seoul to Singapore   Economy Class  ...
# 8078   December 2016            HKG to NAN via ICN   Economy Class  ...
# 8085  September 2016            JFK to TAS via ICN  Business Class  ...
#
#       Food & Beverages  Inflight Entertainment  Value For Money  \
# 13                   5                       5                3
# 19                   1                       1                1
# 25                   4                       4                2
# 30                   5                       3                1
# 36                   3                       3                1
# ...                ...                     ...              ...
# 8039                 1                       4                1
# 8048                 4                       4                2
# 8061                 4                       2                1
# 8078                 4                       3                2
# 8085                 3                       4                1
#
#       Overall Rating  Recommended  Sentiment  \
# 13                 2          yes          0
# 19                 2           no          0
# 25                 2           no          0
# 30                 1           no          0
# 36                 1           no          0
# ...              ...          ...        ...
# 8039               1           no          0
# 8048               2           no          0
# 8061               1           no          0
# 8078               1           no          0
# 8085               1           no          0
#
#                                               Reviews_1  \
# 13    one last busi class passeng board, went seat o...
# 19    flew sq217 singapor melbourn 4th januari. my f...
# 25    we made phuket-singapor round trip exemplari, ...
# 30    no inflight entertain. ye, talk singapor airli...
# 36    we horrif check-in experi singapor airlin nov....
# ...                                                 ...
# 8039  bangkok atlanta via seoul. my husband book fli...
# 8048  seoul hanoi. wish regist absolut disgust total...
# 8061  singapor seoul return. never take korean air a...
# 8078  hong kong nadi, fiji via seoul. it first fligh...
# 8085  new york jfk tashkent via seoul incheon. thi w...
#
#       vader_polarity_compound  \
# 13                     0.8126
# 19                     0.8290
# 25                     0.6369
# 30                     0.8074
# 36                     0.9390
# ...                       ...
# 8039                   0.9118
# 8048                   0.7018
# 8061                   0.6948
# 8078                   0.9050
# 8085                   0.7712
#
#                                   vader_polarity_scores  \
# 13    {'neg': 0.02, 'neu': 0.867, 'pos': 0.113, 'com...
# 19    {'neg': 0.088, 'neu': 0.784, 'pos': 0.128, 'co...
# 25    {'neg': 0.04, 'neu': 0.905, 'pos': 0.056, 'com...
# 30    {'neg': 0.04, 'neu': 0.786, 'pos': 0.174, 'com...
# 36    {'neg': 0.063, 'neu': 0.827, 'pos': 0.11, 'com...
# ...                                                 ...
# 8039  {'neg': 0.046, 'neu': 0.839, 'pos': 0.115, 'co...
# 8048  {'neg': 0.075, 'neu': 0.811, 'pos': 0.114, 'co...
# 8061  {'neg': 0.109, 'neu': 0.699, 'pos': 0.191, 'co...
# 8078  {'neg': 0.125, 'neu': 0.679, 'pos': 0.196, 'co...
# 8085  {'neg': 0.077, 'neu': 0.784, 'pos': 0.138, 'co...
#
#       textblob_polarity_compound
# 13                      0.209259
# 19                     -0.040625
# 25                      0.107744
# 30                      0.186667
# 36                      0.105269
# ...                          ...
# 8039                    0.161905
# 8048                    0.055556
# 8061                   -0.168056
# 8078                    0.092121
# 8085                   -0.032623
#
# [743 rows x 22 columns]

# %%
# Get unique values of 'Overall Rating' column and sort them in ascending order
unique_tags = sorted(data['Sentiment'].unique())

# Loop through sorted unique tags
for tag in unique_tags:
    print('--' * 40)
    print(' ' * 30, f'Sentiment: {tag}')
    functions.histogram(data[data['Sentiment'] == tag]['vader_polarity_compound'])
    print('')
# Out:
# --------------------------------------------------------------------------------
#                                Sentiment: 0
# --------------------------------------------------------------------------------
#                                Sentiment: 1
# --------------------------------------------------------------------------------
#                                Sentiment: 2

# %%
unique_sentiments = sorted(data['Sentiment'].unique())
import matplotlib.pyplot as plt
# Loop through sorted unique sentiments
for sentiment in unique_sentiments:
    print('--' * 55)
    print(' ' * 50, f'Sentiment: {sentiment}')
    
    # Get Vader polarity scores for the current sentiment
    vader_scores = data[data['Sentiment'] == sentiment]['vader_polarity_scores']

    # Plot histogram for each polarity score
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 3, 1)
    plt.hist(vader_scores.apply(lambda x: x['pos']), bins=20, color='blue', alpha=0.7)
    plt.title('Positive Polarity Scores')
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 2)
    plt.hist(vader_scores.apply(lambda x: x['neg']), bins=20, color='red', alpha=0.7)
    plt.title('Negative Polarity Scores')
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 3)
    plt.hist(vader_scores.apply(lambda x: x['neu']), bins=20, color='green', alpha=0.7)
    plt.title('Neutral Polarity Scores')
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()
# Out:
# --------------------------------------------------------------------------------------------------------------
#                                                    Sentiment: 0
# --------------------------------------------------------------------------------------------------------------
#                                                    Sentiment: 1
# --------------------------------------------------------------------------------------------------------------
#                                                    Sentiment: 2

# %%
import seaborn as sns
score_graph = sns.displot(data["vader_polarity_compound"], kde=True, bins=5)
plt.show()

# %%
data['Sentiment'].unique()
# Out:
# array([2, 0, 1])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the data based on the condition

for i in data['Sentiment'].unique():
    filtered_data = data[data['Sentiment'] == i]

# Plot the boxplot
    print(f'Sentiment {i}')
    sns.boxplot(data=filtered_data, x="vader_polarity_compound")
    plt.show()
# Out:
# Sentiment 2
# Sentiment 0
# Sentiment 1

# %% [markdown]
# ## Text Blob

# %%
def textblob_sa(song):

    # Get the polarity (compounded polarity scores) for the song
    polarity = TextBlob(song).sentiment.polarity

    return polarity

# %%
data["textblob_polarity_compound"] = data["Reviews_1"].apply(lambda song : textblob_sa(str(song)))

# %%
data.sample(5)
# Out:
#                                        Title           Name Review Date  \
# 3030  they don't live up to their reputation  Caroline Lane  2022-08-25
# 3271      nice flight, I would not rush back      P Callino  2019-12-27
# 4041           distinctly average experience  Adele Malcolm  2016-12-25
# 918           frequent drinks brought around      A Hardill  2016-07-30
# 2554              be aware if flight delayed       R Clarke  2016-05-22
#
#                  Airline Verified  \
# 3030            Emirates    False
# 3271            Emirates     True
# 4041            Emirates     True
# 918   Singapore Airlines     True
# 2554       Qatar Airways    False
#
#                                                 Reviews Type of Traveller  \
# 3030    After being concerned about our Qantas BC fl...    Couple Leisure
# 3271    Sydney to Dubai in first class was not amazi...      Solo Leisure
# 4041    This was the 2nd leg of our journey from Gat...    Couple Leisure
# 918     Barcelona to Sao Paulo. First flight with Si...      Solo Leisure
# 2554    Be aware if your flight is delayed. QR1111 B...      Solo Leisure
#
#         Month Flown                          Route           Class  ...  \
# 3030    August 2022     Beirut to Sydney via Dubai  Business Class  ...
# 3271  December 2019  New York to Kolkata via Dubai     First Class  ...
# 4041  December 2016             JFK to MAA via DXB  Business Class  ...
# 918    January 2016                     SIN to MEL   Economy Class  ...
# 2554       May 2016                     DOH to SYD  Business Class  ...
#
#       Food & Beverages  Inflight Entertainment  Value For Money  \
# 3030                 1                       3                3
# 3271                 3                       3                3
# 4041                 2                       4                3
# 918                  2                       4                5
# 2554                 5                       5                4
#
#       Overall Rating  Recommended  Sentiment  \
# 3030               4           no          1
# 3271               6          yes          1
# 4041               5           no          1
# 918                9          yes          2
# 2554               4          yes          1
#
#                                               Reviews_1  \
# 3030  after concern qanta bc flight singapor issu, r...
# 3271  sydney dubai first class amaz nice. the servic...
# 4041  thi 2nd leg journey gatwick ho chi minh citi e...
# 918   barcelona sao paulo. first flight singapor air...
# 2554  be awar flight delay. qr1111 bahrain doha dela...
#
#       vader_polarity_compound  \
# 3030                   0.7003
# 3271                   0.9756
# 4041                   0.9686
# 918                    0.9260
# 2554                   0.5574
#
#                                   vader_polarity_scores  \
# 3030  {'neg': 0.086, 'neu': 0.78, 'pos': 0.133, 'com...
# 3271  {'neg': 0.061, 'neu': 0.684, 'pos': 0.255, 'co...
# 4041  {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'comp...
# 918   {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'comp...
# 2554  {'neg': 0.116, 'neu': 0.737, 'pos': 0.146, 'co...
#
#       textblob_polarity_compound
# 3030                   -0.079545
# 3271                    0.280000
# 4041                    0.252778
# 918                     0.341667
# 2554                    0.372222
#
# [5 rows x 22 columns]

# %%
data.groupby('Sentiment')['textblob_polarity_compound'].describe()
# Out:
#             count      mean       std   min       25%       50%       75%  max
# Sentiment
# 0          3022.0 -0.006360  0.191770 -1.00 -0.100852  0.000000  0.095979  1.0
# 1          1672.0  0.134014  0.188282 -0.75  0.013687  0.131897  0.247851  1.0
# 2          3406.0  0.294672  0.196097 -0.50  0.166705  0.283333  0.404167  1.0

# %%
data.loc[(data['textblob_polarity_compound'] > 0.5) & (data['Sentiment'] == 0)]
# Out:
#                                            Title                      Name  \
# 1231  informed that there are technical problems                 E Koehler
# 1996                              not that great  Ramachandran Ashok Kumar
# 2529                          a great experience                Susan John
# 2552                        seat was comfortable                Ming Zhang
# 3001                    took a fine of 200 euros                B Gartonov
# 3110         packed liked sardines despite Covid                  C Harcal
# 3348       airline which differentiate customers                 P Chanhal
# 3557                   unhappy with the services                 M Gaurang
# 3564                    terrible the service was                 H Pansari
# 3627                 Emirates is losing the plot        Hans Mitterlechner
# 3924             both times denied lounge access            Claire Simpson
# 4007                     the pain and discomfort                 Tam Lyall
# 4541               Really lousy customer service               Abdul Azizi
# 4577                     Application not working        George Venetsianos
# 5019       economy they do not serve any alcohol                  K Barmic
# 5541           avoid these unprofessional people                John Mbuli
# 5570                    I am really disappointed                  M Kahana
# 5659                             lost my baggage                  W Barude
# 6325                   my baggage didn't make it            Nour El Khoury
# 6607                         were put on standby            Kristen DePaul
# 6649                Bureaucracy over flexibility                 P Gassane
# 6706               horrible start to the holiday              Luke Johnson
# 6935                         the legroom is tiny                     N Lee
# 7112           my luggage did not arrive with me               Grace Limbo
#
#      Review Date                 Airline Verified  \
# 1231  2022-11-27           Qatar Airways     True
# 1996  2018-11-17           Qatar Airways     True
# 2529  2016-07-13           Qatar Airways     True
# 2552  2016-05-27           Qatar Airways     True
# 3001  2022-10-30                Emirates     True
# 3110  2022-01-08                Emirates     True
# 3348  2019-08-27                Emirates     True
# 3557  2018-10-17                Emirates     True
# 3564  2018-10-11                Emirates     True
# 3627  2018-07-15                Emirates     True
# 3924  2017-06-07                Emirates    False
# 4007  2017-02-02                Emirates    False
# 4541  2023-08-31        Turkish Airlines    False
# 4577  2023-07-21        Turkish Airlines     True
# 5019  2021-06-16        Turkish Airlines     True
# 5541  2018-12-15        Turkish Airlines    False
# 5570  2018-11-08        Turkish Airlines     True
# 6706   December 2017              Bogota to Rome via Paris   Economy Class
# 6935      April 2023  Hong Kong to Vancouver via Hong Kong   Economy Class
# 7112       June 2019        London to Manila via Hong Kong   Economy Class
#
#       ...  Food & Beverages  Inflight Entertainment  Value For Money  \
# 1231  ...                 5                       5                1
# 1996  ...                 5                       5                1
# 2529  ...                 1                       3                5
# 2552  ...                 1                       4                4
# 3001  ...                 1                       1                1
# 3110  ...                 1                       4                1
# 3348  ...                 1                       2                1
# 3557  ...                 5                       5                1
# 3564  ...                 2                       5                1
# 3627  ...                 3                       4                2
# 3924  ...                 1                       1                2
# 4007  ...                 4                       4                2
# 4541  ...                 5                       1                1
# 4577  ...                 5                       3                1
# 5019  ...                 3                       5                1
# 5541  ...                 2                       4                1
# 5570  ...                 3                       3                2
# 5659  ...                 3                       3                1
# 6325  ...                 1                       4                3
# 6607  ...                 1                       4                1
# 6649  ...                 1                       4                1
# 6706  ...                 3                       3                3
# 6935  ...                 3                       4                1
# 7112  ...                 1                       4                1
#
#       Overall Rating  Recommended  Sentiment  \
# 1231               1           no          0
# 1996               1           no          0
# 2529               3          yes          0
# 2552               1          yes          0
# 3001               1           no          0
# 3110               1           no          0
# 3348               2           no          0
# 3557               2           no          0
# 3564               3           no          0
# 3627               2           no          0
# 3924               2           no          0
# 4007               3           no          0
# 4541               1           no          0
# 4577               1           no          0
# 5019               1           no          0
# 5541               1           no          0
# 5570               2           no          0
# 5659               1           no          0
# 6325               1           no          0
# 6607               2           no          0
# 6649               1           no          0
# 6706               1           no          0
# 6935               1           no          0
# 7112               1           no          0
#
#                                               Reviews_1  \
# 1231  the flight singapor okay best, seat close. foo...
# 1996  bangalor nice via doha. my experi great comfor...
# 2529  excel servic great experi qatar airway fli doh...
# 2552  return london heathrow shanghai qatar airway. ...
# 3001  emir, togeth agent, engag decept fraud exchang...
# 3110  have flown section busi except rerun sector du...
# 3348  toronto mumbai via dubai. consid airlin best. ...
# 3557  birmingham kathmandu via dubai. emir use best ...
# 3564  jakarta london via dubai. shock terribl servic...
# 3627  rome dubai. think emir lose plot. servic avera...
# 3924  mauritiu london via dubai. veri disappoint emi...
# 4007  pari melbourn via dubai. economi class never g...
# 4541  realli lousi custom servic, push side like tra...
# 4577  flight beij istanbul. applic work, allow proce...
# 5019  befor thought good airlin, anymor. dure covid ...
# 5541  pari dar es salaam via istanbul. turkish airli...
# 5570  realli disappoint experi novemb flight number ...
# 5659  minsk beirut via istanbul. turkish airlin lost...
# 6325  went month nice, arriv nice baggag came. in re...
# 6607  pari geneva. we made flight reserv month ago c...
# 6649  milan pari. ground staff incompet, rigid impol...
# 6706  flew air franc london heathrow mauritiu via pa...
# 6935  they serv bottl water plane. took cathay year ...
# 7112  london manila via hong kong. land manila even ...
#
#       vader_polarity_compound  \
# 1231                   0.7430
# 1996                   0.9840
# 2529                   0.9118
# 2552                   0.9628
# 3001                  -0.7955
# 3110                   0.9020
# 3348                   0.8658
# 3557                   0.8316
# 3564                   0.9042
# 3627                   0.3612
# 3924                   0.0000
# 4007                  -0.6902
# 4541                   0.8442
# 4577                   0.9468
# 5019                   0.4404
# 5541                   0.3147
# 5570                   0.8271
# 5659                   0.5423
# 6325                   0.5267
# 6607                   0.5093
# 6649                   0.4404
# 6706                   0.4926
# 6935                   0.6808
# 7112                  -0.7251
#
#                                   vader_polarity_scores  \
# 1231  {'neg': 0.054, 'neu': 0.765, 'pos': 0.181, 'co...
# 1996  {'neg': 0.0, 'neu': 0.447, 'pos': 0.553, 'comp...
# 2529  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...
# 2552  {'neg': 0.0, 'neu': 0.591, 'pos': 0.409, 'comp...
# 3001  {'neg': 0.232, 'neu': 0.68, 'pos': 0.088, 'com...
# 3110  {'neg': 0.04, 'neu': 0.713, 'pos': 0.248, 'com...
# 3348  {'neg': 0.0, 'neu': 0.771, 'pos': 0.229, 'comp...
# 3557  {'neg': 0.025, 'neu': 0.809, 'pos': 0.165, 'co...
# 3564  {'neg': 0.035, 'neu': 0.763, 'pos': 0.202, 'co...
# 3627  {'neg': 0.118, 'neu': 0.718, 'pos': 0.163, 'co...
# 3924  {'neg': 0.137, 'neu': 0.753, 'pos': 0.11, 'com...
# 4007  {'neg': 0.188, 'neu': 0.707, 'pos': 0.105, 'co...
# 4541  {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'comp...
# 4577  {'neg': 0.039, 'neu': 0.676, 'pos': 0.285, 'co...
# 5019  {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'comp...
# 5541  {'neg': 0.156, 'neu': 0.712, 'pos': 0.132, 'co...
# 5570  {'neg': 0.11, 'neu': 0.559, 'pos': 0.331, 'com...
# 5659  {'neg': 0.085, 'neu': 0.701, 'pos': 0.214, 'co...
# 6325  {'neg': 0.082, 'neu': 0.709, 'pos': 0.209, 'co...
# 6607  {'neg': 0.027, 'neu': 0.9, 'pos': 0.072, 'comp...
# 6649  {'neg': 0.06, 'neu': 0.803, 'pos': 0.137, 'com...
# 6706  {'neg': 0.063, 'neu': 0.797, 'pos': 0.14, 'com...
# 6935  {'neg': 0.042, 'neu': 0.83, 'pos': 0.128, 'com...
# 7112  {'neg': 0.16, 'neu': 0.764, 'pos': 0.076, 'com...
#
#       textblob_polarity_compound
# 1231                    0.550000
# 1996                    0.685714
# 2529                    0.800000
# 2552                    0.513333
# 3001                    0.520833
# 3110                    1.000000
# 3348                    0.642857
# 3557                    0.850000
# 3564                    0.511429
# 3627                    0.521429
# 3924                    0.800000
# 4007                    0.608333
# 4541                    0.800000
# 4577                    0.600000
# 5019                    0.700000
# 5541                    0.937500
# 5570                    0.550000
# 5659                    0.700000
# 6325                    0.600000
# 6607                    0.600000
# 6649                    0.600000
# 6706                    0.750000
# 6935                    0.583333
# 7112                    1.000000
#
# [24 rows x 22 columns]

# %%
observation = data.loc[6607]
observation['Reviews']
# Out:
# '  Paris to Geneva. We made our flight reservations over 6 months ago and because we did not check in online 36 hours before, 3 or the 4 of us were put on standby! 2 of us were already able to get our tickets and we are still waiting to see if the 4th person in our party will make the flight. We have a 4 hour drive that we will have to wait on him for. What kind of airline gives their paying passengers tickets away just because they don’t check in online?  I also ended up paying $150 to check bags. '

# %%
# Get unique values of 'Overall Rating' column and sort them in ascending order
unique_tags = sorted(data['Sentiment'].unique())

# Loop through sorted unique tags
for tag in unique_tags:
    print('--' * 40)
    print(' ' * 30, f'Sentiment: {tag}')
    functions.histogram(data[data['Sentiment'] == tag]['textblob_polarity_compound'])
    print('')
# Out:
# --------------------------------------------------------------------------------
#                                Sentiment: 0
# --------------------------------------------------------------------------------
#                                Sentiment: 1
# --------------------------------------------------------------------------------
#                                Sentiment: 2
