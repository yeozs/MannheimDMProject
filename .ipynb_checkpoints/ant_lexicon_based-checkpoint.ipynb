# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Vader" data-toc-modified-id="Vader-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Vader</a></span><ul class="toc-item"><li><span><a href="#Vader" data-toc-modified-id="Vader-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Vader</a></span></li></ul></li><li><span><a href="#Text-Blob" data-toc-modified-id="Text-Blob-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Text Blob</a></span></li><li><span><a href="#AFINN" data-toc-modified-id="AFINN-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>AFINN</a></span></li><li><span><a href="#Comparing-Methods" data-toc-modified-id="Comparing-Methods-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Comparing Methods</a></span></li></ul></div>

# %% [markdown]
# # Libraries

# %%
import pandas as pd


import nltk

# Stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# External file
import random_functions
import lexicon_based


#
pd.set_option('display.max_columns', None)

# Ignore all warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# functions = [func for func in dir(lexicon_based) if callable(getattr(lexicon_based, func))]

# # Print the list of functions
# print("Functions in the external module:")
# for func in functions:
#     print(func)

# %% [markdown]
# # Data

# %%
data = pd.read_csv('/Users/antoniooliveira/Downloads/airlines_reviews.csv')

# %%
data.head()
# Out:
#                                   Title              Name Review Date  \
# 0                    Flight was amazing  Alison Soetantyo  2024-03-01
# 1  seats on this aircraft are dreadful      Robert Watson  2024-02-21
# 2          Food was plentiful and tasty             S Han  2024-02-20
# 3          “how much food was available          D Laynes  2024-02-19
# 4       “service was consistently good”         A Othman   2024-02-19
#
#               Airline Verified  \
# 0  Singapore Airlines     True
# 1  Singapore Airlines     True
# 2  Singapore Airlines     True
# 3  Singapore Airlines     True
# 4  Singapore Airlines     True
#
#                                              Reviews Type of Traveller  \
# 0    Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1    Booking an emergency exit seat still meant h...      Solo Leisure
# 2    Excellent performance on all fronts. I would...    Family Leisure
# 3   Pretty comfortable flight considering I was f...      Solo Leisure
# 4   The service was consistently good from start ...    Family Leisure
#
#      Month Flown                         Route           Class  Seat Comfort  \
# 0  December 2023          Jakarta to Singapore  Business Class             4
# 1  February 2024           Phuket to Singapore   Economy Class             5
# 2  February 2024        Siem Reap to Singapore   Economy Class             1
# 3  February 2024  Singapore to London Heathrow   Economy Class             5
# 4  February 2024       Singapore to Phnom Penh   Economy Class             5
#
#    Staff Service  Food & Beverages  Inflight Entertainment  Value For Money  \
# 0              4                 4                       4                4
# 1              3                 4                       4                1
# 2              5                 2                       1                5
# 3              5                 5                       5                5
# 4              5                 5                       5                5
#
#    Overall Rating Recommended
# 0               9         yes
# 1               3          no
# 2              10         yes
# 3              10         yes
# 4              10         yes

# %%
#Create new function to convert Rating scores to 3 categories
#1-4, 5-6, 7-10 forms negative, neutral, positive [0,1,2]
def score_convert_senti(score):
    if score <= 4:
        return -1
    #elif score >= 5 and score <= 6: #and score <= 6
    #    return 0
    elif score >=7:
        return 1

#Create new column, convert scoring into 3 categories
data["Sentiment"] = data["Overall Rating"].apply(score_convert_senti)

#dataset has derived sentiment column added
data.head()
# Out:
#                                   Title              Name Review Date  \
# 0                    Flight was amazing  Alison Soetantyo  2024-03-01
# 1  seats on this aircraft are dreadful      Robert Watson  2024-02-21
# 2          Food was plentiful and tasty             S Han  2024-02-20
# 3          “how much food was available          D Laynes  2024-02-19
# 4       “service was consistently good”         A Othman   2024-02-19
#
#               Airline Verified  \
# 0  Singapore Airlines     True
# 1  Singapore Airlines     True
# 2  Singapore Airlines     True
# 3  Singapore Airlines     True
# 4  Singapore Airlines     True
#
#                                              Reviews Type of Traveller  \
# 0    Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1    Booking an emergency exit seat still meant h...      Solo Leisure
# 2    Excellent performance on all fronts. I would...    Family Leisure
# 3   Pretty comfortable flight considering I was f...      Solo Leisure
# 4   The service was consistently good from start ...    Family Leisure
#
#      Month Flown                         Route           Class  Seat Comfort  \
# 0  December 2023          Jakarta to Singapore  Business Class             4
# 1  February 2024           Phuket to Singapore   Economy Class             5
# 2  February 2024        Siem Reap to Singapore   Economy Class             1
# 3  February 2024  Singapore to London Heathrow   Economy Class             5
# 4  February 2024       Singapore to Phnom Penh   Economy Class             5
#
#    Staff Service  Food & Beverages  Inflight Entertainment  Value For Money  \
# 0              4                 4                       4                4
# 1              3                 4                       4                1
# 2              5                 2                       1                5
# 3              5                 5                       5                5
# 4              5                 5                       5                5
#
#    Overall Rating Recommended  Sentiment
# 0               9         yes        1.0
# 1               3          no       -1.0
# 2              10         yes        1.0
# 3              10         yes        1.0
# 4              10         yes        1.0

# %% [markdown]
# # Preprocessing for Lexicon-based

# %%
 data['Reviews_1'] = data['Reviews'].apply(lambda text: random_functions.preprocessor(text,
                 lowercase=False, 
                 leave_punctuation = True, 
                 remove_stopwords = True,
                 stop_words = stop_words,
                 correct_spelling = False, 
                 lemmatization=False, 
                 porter_stemming=True,
                 tokenized_output=False, 
                 sentence_output=False,
                 remove_emojis=False))

# %%
data['Reviews_1'].sample()
# Out:
# 2247    flew salalah, oman frankfurt via doha qatar ai...
# Name: Reviews_1, dtype: object

# %% [markdown]
# ## Vader

# %%
data.dropna(inplace=True)

# %%
data["vader_polarity_compound"] = data["Reviews_1"].apply(lambda review : lexicon_based.vader_algorithm(str(review)))

data["vader_polarity_scores"] = data["Reviews_1"].apply(lambda review : lexicon_based.vader_algorithm(str(review), compound = False))

# %%
data.groupby('Sentiment')['vader_polarity_compound'].describe()
# Out:
#             count      mean       std     min     25%     50%      75%     max
# Sentiment
# -1.0       3022.0 -0.129558  0.650024 -0.9914 -0.7430 -0.2732  0.49390  0.9944
#  1.0       3915.0  0.784675  0.316763 -0.9300  0.7717  0.9081  0.95575  0.9984

# %%
data.loc[(data['vader_polarity_compound'] > 0) & (data['Sentiment'] == -1)]

# use Overall Rating as a Ground truth and compare with vader
# see how it varies accross the year
# make a different class split
# Out:
#                                              Title                   Name  \
# 13          regional seat was really uncomfortable                  L Hee
# 16    agent took out travel insurance on my behalf            Niki Kladis
# 19                 not fly with them in the future                H Paran
# 20                        Barely any room to move               Sean Wise
# 24              allocated us three different seats  Sudipta Bandyopadhyay
# ...                                            ...                    ...
# 8048                 totally unacceptable service         Nicholas Hurley
# 8061                 never take Korean Air anymore                 Y Peck
# 8078                      my last flight with them              Julia Lee
# 8083                  counter service was horrible            S Vistaphon
# 8085                       the worst Asian airline               G Nazano
#
#      Review Date             Airline Verified  \
# 13    2024-02-16  Singapore Airlines     True
# 16    2024-01-29  Singapore Airlines     True
# 19    2024-01-18  Singapore Airlines     True
# 20    2024-01-16  Singapore Airlines     True
# 24    2023-12-31  Singapore Airlines     True
# ...          ...                 ...      ...
# 8048  2017-09-20          Korean Air     True
# 8061  2017-05-13          Korean Air    False
# 8078  2016-12-13          Korean Air     True
# 8083  2016-10-17          Korean Air     True
# 8085  2016-09-21          Korean Air     True
#
#                                                 Reviews Type of Traveller  \
# 13      I was one of the last business class passeng...      Solo Leisure
# 16      For my final trip booked for July 2024, Sing...      Solo Leisure
# 19      I flew on SQ217 from Singapore to Melbourne ...    Couple Leisure
# 20      Barely any room to move, woke up to getting ...    Family Leisure
# 24      We booked our ticket well in advance for our...    Family Leisure
# ...                                                 ...               ...
# 8048    Seoul to Hanoi. I wish to register my absolu...          Business
# 8061    Singapore to Seoul return. I will never take...    Family Leisure
# 8078    Hong Kong to Nadi, Fiji via Seoul. It was my...      Solo Leisure
# 8083    Washington to Seoul Incheon. The Korean Air ...      Solo Leisure
# 8085    New York JFK to Tashkent via Seoul Incheon. ...          Business
#
#          Month Flown                             Route           Class  \
# 13      January 2024         Singapore to Tokyo Haneda  Business Class
# 16     December 2023  Sydney to Istanbul via Singapore  Business Class
# 19      January 2024            Singapore to Melbourne   Economy Class
# 20      January 2024             Singapore to Adelaide   Economy Class
# 24     December 2023                Singapore to Perth   Economy Class
# ...              ...                               ...             ...
# 8048  September 2017                    Seoul to Hanoi   Economy Class
# 8061        May 2017                Seoul to Singapore   Economy Class
# 8078   December 2016                HKG to NAN via ICN   Economy Class
# 8083    October 2016                        IAD to ICN   Economy Class
# 8085  September 2016                JFK to TAS via ICN  Business Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 13               5              1                 5                       5
# 16               4              5                 4                       5
# 19               1              1                 1                       1
# 20               1              5                 2                       3
# 24               3              4                 3                       3
# ...            ...            ...               ...                     ...
# 8048             5              4                 4                       4
# 8061             5              5                 4                       2
# 8078             5              3                 4                       3
# 8083             2              5                 5                       3
# 8085             4              5                 3                       4
#
#       Value For Money  Overall Rating Recommended  Sentiment  \
# 13                  3               2         yes       -1.0
# 16                  3               2          no       -1.0
# 19                  1               2          no       -1.0
# 20                  1               1          no       -1.0
# 24                  1               1          no       -1.0
# ...               ...             ...         ...        ...
# 8048                2               2          no       -1.0
# 8061                1               1          no       -1.0
# 8078                2               1          no       -1.0
# 8083                2               3          no       -1.0
# 8085                1               1          no       -1.0
#
#                                               Reviews_1  \
# 13    one last busi class passeng board, went seat o...
# 16    for final trip book juli 2024, singapor cancel...
# 19    flew sq217 singapor melbourn 4th januari. my f...
# 20    bare room move, woke get knee crush passeng fr...
# 24    we book ticket well advanc return trip india c...
# ...                                                 ...
# 8048  seoul hanoi. wish regist absolut disgust total...
# 8061  singapor seoul return. never take korean air a...
# 8078  hong kong nadi, fiji via seoul. it first fligh...
# 8083  washington seoul incheon. the korean air count...
# 8085  new york jfk tashkent via seoul incheon. thi w...
#
#       vader_polarity_compound  \
# 13                     0.8126
# 16                     0.1280
# 19                     0.8290
# 20                     0.2263
# 24                     0.2263
# ...                       ...
# 8048                   0.7018
# 8061                   0.6948
# 8078                   0.9050
# 8083                   0.0772
# 8085                   0.7712
#
#                                   vader_polarity_scores
# 13    {'neg': 0.02, 'neu': 0.867, 'pos': 0.113, 'com...
# 16    {'neg': 0.059, 'neu': 0.874, 'pos': 0.067, 'co...
# 19    {'neg': 0.088, 'neu': 0.784, 'pos': 0.128, 'co...
# 20    {'neg': 0.069, 'neu': 0.823, 'pos': 0.108, 'co...
# 24    {'neg': 0.059, 'neu': 0.862, 'pos': 0.079, 'co...
# ...                                                 ...
# 8048  {'neg': 0.075, 'neu': 0.811, 'pos': 0.114, 'co...
# 8061  {'neg': 0.109, 'neu': 0.699, 'pos': 0.191, 'co...
# 8078  {'neg': 0.125, 'neu': 0.679, 'pos': 0.196, 'co...
# 8083  {'neg': 0.0, 'neu': 0.982, 'pos': 0.018, 'comp...
# 8085  {'neg': 0.077, 'neu': 0.784, 'pos': 0.138, 'co...
#
# [1214 rows x 21 columns]

# %%
observation = data.loc[8078]
observation['Reviews']
# Out:
# '  Hong Kong to Nadi, Fiji via Seoul. It was my first flight with Korean Air and it certainly is the last one. Whoever told me it is one of the best, seems to not have traveled with any other company apart from some Ryanair or American Airlines, which, ironically, are better than Korean Air as far as I am concerned.  My gluten free food - I don\'t know exactly what they put there, but my strong medicine couldn\'t help me. When I asked for half a lemon and warm water, which usually helps me a tiny bit at least to calm down when I am trapped on the plane without access to medical help, they gave me a small slice and were visibly annoyed when I asked for more lemon. The service onboard is outrageous. Air-hostesses are more concerned with how they look instead of how they work. Rude answers to simple questions, blocking the way to lavatory while reading something and ignoring me saying "excuse me" a few times, not even saying good bye when passengers were leaving the plane. These are just some examples. On top of those, my suitcase was broken. The mess they created out of this situation is unbelievable. There\'s nothing straightforward, even to proceed with compensation they ask you to sign a weird document to state you have already received the money (what?). To get the money, you need to go to the airport to get cash from their representative. Imagine being on a small island with a broken luggage not knowing where even to buy a new one that you will like and will not want to throw away to waste. Entertainment system is a joke. Definitely my last flight with them. '

# %%
# Get unique values of 'Overall Rating' column and sort them in ascending order
unique_tags = sorted(data['Sentiment'].unique())

# Loop through sorted unique tags
for tag in unique_tags:
    print('--' * 40)
    print(' ' * 30, f'Sentiment: {tag}')
    random_functions.histogram(data[data['Sentiment'] == tag]['vader_polarity_compound'])
    print('')
# Out:
# --------------------------------------------------------------------------------
#                                Sentiment: -1.0
# --------------------------------------------------------------------------------
#                                Sentiment: 1.0

# %%
unique_sentiments = sorted(data['Sentiment'].unique())
import matplotlib.pyplot as plt
# Loop through sorted unique sentiments
for sentiment in unique_sentiments:
    print('--' * 55)
    print(' ' * 50, f'Sentiment: {sentiment}')
    
    # Get Vader polarity scores for the current sentiment
    vader_scores = data[data['Sentiment'] == sentiment]['vader_polarity_scores']

    # Plot histogram for each polarity score
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 3, 1)
    plt.hist(vader_scores.apply(lambda x: x['pos']), bins=20, color='blue', alpha=0.7)
    plt.title('Positive Polarity Scores')
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 2)
    plt.hist(vader_scores.apply(lambda x: x['neg']), bins=20, color='red', alpha=0.7)
    plt.title('Negative Polarity Scores')
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 3)
    plt.hist(vader_scores.apply(lambda x: x['neu']), bins=20, color='green', alpha=0.7)
    plt.title('Neutral Polarity Scores')
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns
score_graph = sns.displot(data["vader_polarity_compound"], kde=True, bins=5)
plt.show()

# %%
data['Sentiment'].unique()
# Out:
# array([ 9,  3, 10,  5,  4,  2,  8,  1,  7,  6])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the data based on the condition

for i in data['Sentiment'].unique():
    filtered_data = data[data['Sentiment'] == i]

# Plot the boxplot
    print(f'Sentiment {i}')
    sns.boxplot(data=filtered_data, x="vader_polarity_compound")
    plt.show()
# Out:
# Sentiment 9
# Sentiment 3
# Sentiment 10
# Sentiment 5
# Sentiment 4
# Sentiment 2
# Sentiment 8
# Sentiment 1
# Sentiment 7
# Sentiment 6

# %% [markdown]
# ### Vader

# %%
data["vader_polarity_compound_2"] = data["Title"].apply(lambda song : vader_sa(str(song)))

data["vader_polarity_scores_2"] = data["Title"].apply(lambda song : vader_sa(str(song), compound = False))

# %%
data.groupby('Sentiment')['vader_polarity_compound'].describe()
# Out:
#             count      mean       std     min     25%      50%     75%     max
# Sentiment
# 0          3022.0 -0.129558  0.650024 -0.9914 -0.7430 -0.27320  0.4939  0.9944
# 1          1672.0  0.422056  0.588594 -0.9868  0.0258  0.68080  0.9022  0.9938
# 2          3406.0  0.802642  0.293201 -0.9300  0.7906  0.91255  0.9571  0.9984

# %%
# Get unique values of 'Overall Rating' column and sort them in ascending order
unique_tags = sorted(data['Sentiment'].unique())

# Loop through sorted unique tags
for tag in unique_tags:
    print('--' * 40)
    print(' ' * 30, f'Sentiment: {tag}')
    functions.histogram(data[data['Sentiment'] == tag]['vader_polarity_compound_2'])
    print('')
# Out:
# --------------------------------------------------------------------------------
#                                Sentiment: 0
# --------------------------------------------------------------------------------
#                                Sentiment: 1
# --------------------------------------------------------------------------------
#                                Sentiment: 2

# %%
# maybe join scores of title + reviews and give them weights

# %% [markdown]
# ## Text Blob

# %%
from textblob import TextBlob

# %%
def textblob_sa(song):

    # Get the polarity (compounded polarity scores) for the song
    polarity = TextBlob(song).sentiment.polarity

    return polarity

# %%
data["textblob_polarity_compound"] = data["Reviews_1"].apply(lambda song : textblob_sa(str(song)))

# %%
data.sample(5)
# Out:
#                                Title           Name Review Date  \
# 1993           attentive cabin staff      A Thawani  2018-11-18
# 3602                Goodbye Emirates      K Jirstan  2018-08-16
# 36    Never again Singapore Airlines    Vibor Cilic  2023-11-18
# 2116         An excellent experience      A Althani  2018-04-28
# 4938      Seats were typical economy  Thomas Echter  2021-11-01
#
#                  Airline Verified  \
# 1993       Qatar Airways     True
# 3602            Emirates     True
# 36    Singapore Airlines     True
# 2116       Qatar Airways     True
# 4938    Turkish Airlines    False
#
#                                                 Reviews Type of Traveller  \
# 1993    Hong Kong to Doha. Boarding was smooth and t...    Family Leisure
# 3602    Hamburg to Melbourne via Dubai. Have flown E...      Solo Leisure
# 36     We had the most horrific check-in experience ...    Family Leisure
# 2116    Doha to Johannesburg. Early morning start on...    Family Leisure
# 4938    We didn’t expect much (also due to some revi...    Family Leisure
#
#         Month Flown                               Route           Class  \
# 1993  November 2018     New York to Trivandrum via Doha  Business Class
# 3602    August 2018  New York to Johannesburg via Dubai   Economy Class
# 36    November 2023               New York to Frankfurt   Economy Class
# 2116     April 2018    Colombo to Philadelphia via Doha  Business Class
# 4938   October 2021       Boston to Tehran via Istanbul   Economy Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 1993             4              2                 5                       4
# 3602             5              5                 4                       2
# 36               4              4                 3                       3
# 2116             1              4                 5                       5
# 4938             1              1                 5                       4
#
#       Value For Money  Overall Rating Recommended  Sentiment  \
# 1993                3               8         yes        1.0
# 3602                1               1          no       -1.0
# 36                  1               1          no       -1.0
# 2116                3              10         yes        1.0
# 4938                5               8         yes        1.0
#
#                                               Reviews_1  \
# 1993  hong kong doha. board smooth take time, typhoo...
# 3602  hamburg melbourn via dubai. have flown emir ma...
# 36    we horrif check-in experi singapor airlin nov....
# 2116  doha johannesburg. earli morn start older 777 ...
# 4938  we expect much( also due review) trip berlin- ...
#
#       vader_polarity_compound  \
# 1993                   0.0516
# 3602                  -0.6249
# 36                     0.9390
# 2116                   0.9081
# 4938                   0.9004
#
#                                   vader_polarity_scores  \
# 1993  {'neg': 0.134, 'neu': 0.718, 'pos': 0.149, 'co...
# 3602  {'neg': 0.188, 'neu': 0.812, 'pos': 0.0, 'comp...
# 36    {'neg': 0.063, 'neu': 0.827, 'pos': 0.11, 'com...
# 2116  {'neg': 0.047, 'neu': 0.653, 'pos': 0.3, 'comp...
# 4938  {'neg': 0.06, 'neu': 0.738, 'pos': 0.202, 'com...
#
#       textblob_polarity_compound
# 1993                    0.028636
# 3602                   -0.275000
# 36                      0.105269
# 2116                    0.433333
# 4938                    0.152273

# %%
data.groupby('Sentiment')['textblob_polarity_compound'].describe()
# Out:
#             count      mean       std  min       25%       50%       75%  max
# Sentiment
# -1.0       3403.0  0.001733  0.192247 -1.0 -0.094437  0.000000  0.102122  1.0
#  1.0       3915.0  0.282739  0.195777 -0.5  0.155556  0.269643  0.394048  1.0

# %%
data.loc[(data['textblob_polarity_compound'] > 0.5) & (data['Sentiment'] == 0)]
# Out:
# Empty DataFrame
# Columns: [Title, Name, Review Date, Airline, Verified, Reviews, Type of Traveller, Month Flown, Route, Class, Seat Comfort, Staff Service, Food & Beverages, Inflight Entertainment, Value For Money, Overall Rating, Recommended, Sentiment, Reviews_1, vader_polarity_compound, vader_polarity_scores, textblob_polarity_compound]
# Index: []
#
# [0 rows x 22 columns]

# %%
observation = data.loc[6607]
observation['Reviews']
# Out:
# '  Paris to Geneva. We made our flight reservations over 6 months ago and because we did not check in online 36 hours before, 3 or the 4 of us were put on standby! 2 of us were already able to get our tickets and we are still waiting to see if the 4th person in our party will make the flight. We have a 4 hour drive that we will have to wait on him for. What kind of airline gives their paying passengers tickets away just because they don’t check in online?  I also ended up paying $150 to check bags. '

# %%
# Get unique values of 'Overall Rating' column and sort them in ascending order
unique_tags = sorted(data['Sentiment'].unique())

# Loop through sorted unique tags
for tag in unique_tags:
    print('--' * 40)
    print(' ' * 30, f'Sentiment: {tag}')
    random_functions.histogram(data[data['Sentiment'] == tag]['textblob_polarity_compound'])
    print('')
# Out:
# --------------------------------------------------------------------------------
#                                Sentiment: -1.0
# --------------------------------------------------------------------------------
#                                Sentiment: 1.0

# %% [markdown]
# ## AFINN

# %%
# %pip install afinn
# Out:
# Collecting afinn
#   Using cached afinn-0.1.tar.gz (52 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: afinn
#   Building wheel for afinn (setup.py) ... done
#   Created wheel for afinn: filename=afinn-0.1-py3-none-any.whl size=53429 sha256=2dab8ba314670b853be3dd4ed5f120508bb20e1d1e3a3aed0943c5596c730b86
#   Stored in directory: /Users/antoniooliveira/Library/Caches/pip/wheels/ee/d3/a0/f9255ebac29886acb1c28b35b37523f6399677fa06be379f25
# Successfully built afinn
# Installing collected packages: afinn
# Successfully installed afinn-0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from afinn import Afinn

afinn = Afinn()

data['Afinn_polarity_compound'] = data['Reviews_1'].apply(lambda x: 
                                              afinn.score(x))

# %%
data[['Reviews_1', 'Afinn_polarity_compound']]
# Out:
#                                               Reviews_1  \
# 0     flight amaz. the crew onboard flight welcom, g...
# 1     book emerg exit seat still meant huge discomfo...
# 2     excel perform front. would definit choos use a...
# 3     pretti comfort flight consid fli economi class...
# 4     the servic consist good start finish. the cabi...
# ...                                                 ...
# 8095  ke124, brisban incheon( a330) ke867, incheon u...
# 8096  our recent flight fourth trip uk year sydney l...
# 8097  flew korean air bali seoul prestig class( busi...
# 8098  seoul pari korean air. travel triathlon bike, ...
# 8099  the 13 hour flight busi class seoul toronto on...
#
#       Afinn_polarity_compound
# 0                         9.0
# 1                        -7.0
# 2                         0.0
# 3                        11.0
# 4                        14.0
# ...                       ...
# 8095                      2.0
# 8096                     17.0
# 8097                     -5.0
# 8098                     10.0
# 8099                      5.0
#
# [8100 rows x 2 columns]

# %%
data.groupby('Sentiment')['Afinn_polarity_compound'].describe()
# Out:
#             count      mean       std   min  25%  50%   75%   max
# Sentiment
# -1.0       3403.0 -1.416985  6.394564 -37.0 -5.0 -2.0   2.0  40.0
#  1.0       3915.0  9.344828  7.320087 -13.0  4.0  8.0  13.0  71.0

# %%
for i in data['Sentiment'].unique():
    filtered_data = data[data['Sentiment'] == i]

# Plot the boxplot
    print(f'Sentiment {i}')
    sns.boxplot(data=filtered_data, x="Afinn_polarity_compound")
    plt.show()
# Out:
# Sentiment 1.0
# Sentiment -1.0

# %%
# Get unique values of 'Overall Rating' column and sort them in ascending order
unique_tags = sorted(data['Sentiment'].unique())

# Loop through sorted unique tags
for tag in unique_tags:
    print('--' * 40)
    print(' ' * 30, f'Sentiment: {tag}')
    random_functions.histogram(data[data['Sentiment'] == tag]['afinn_normalized_polarity'])
    print('')
# Out:
# --------------------------------------------------------------------------------
#                                Sentiment: -1.0
# --------------------------------------------------------------------------------
#                                Sentiment: 1.0

# %%
data[(data['Sentiment'] == 1) & (data['Afinn_polarity_compound'] > 10)]
# Out:
#                                                   Title  \
# 380                          not recommend this airline
# 428                           unable to select the seat
# 487                               I would not recommend
# 560                              disappointed this time
# 1996                                     not that great
# 2505                    great flat bed seat and pajamas
# 2520                   a good trip and excellent value
# 2552                               seat was comfortable
# 2560                      could not fault Qatar Airways
# 2594                fantastic business class experience
# 2986  definitely don’t get what you paid for on Emir...
# 3359                            venture of cost cutting
# 3549                             bad service, rude crew
# 3567                           the most horrible flight
# 3572                              What is the big fuss?
# 3592                         I was terribly unsatisfied
# 3661                          how overrated Emirates is
# 3684                Incompetence of check-in personnel
# 3693                                   Terrible service
# 3772                         do not expect good service
# 3798                              seats that were tight
# 3812                    unfriendly, arrogant cabin crew
# 4026                           rude and non-cooperative
# 4532                       feel frustrated and let down
# 4535                             My luggage was damaged
# 5124                  cost-cutting on whatever they can
# 5404                        rude and lacked any empathy
# 5513                     really discriminate passengers
# 5661                          way behind other carriers
# 6061                         lousy Miles&Smiles service
# 7010                           many touch points missed
# 7083                          no Cathay Pacific counter
# 7274                    Wouldn't recommend this airline
# 8078                           my last flight with them
#
#                           Name Review Date                 Airline Verified  \
# 380                    G Beyne  2019-11-02      Singapore Airlines     True
# 428                    R Hicks  2019-08-31      Singapore Airlines     True
# 487              Andrew Tucker  2019-05-01      Singapore Airlines     True
# 560              Jiaolong Yang  2018-12-14      Singapore Airlines     True
# 1996  Ramachandran Ashok Kumar  2018-11-17           Qatar Airways     True
# 2505                  P Werton  2016-09-08           Qatar Airways     True
# 2520               B Medraulin  2016-07-24           Qatar Airways    False
# 2552                Ming Zhang  2016-05-27           Qatar Airways     True
# 2560            Michael Davies  2016-05-18           Qatar Airways    False
# 2594                   A Ahmed  2016-03-26           Qatar Airways    False
# 2986            Yasmin Strange  2023-01-05                Emirates    False
# 3359              Yusuf Barrie  2019-08-12                Emirates     True
# 3549                  G Macino  2018-11-06                Emirates     True
# 3567               Matthew Lee  2018-10-07                Emirates     True
# 3572             Haissam Rahal  2018-09-27                Emirates     True
# 3592                  C Sargin  2018-08-28                Emirates     True
# 3661          Brooke McDermott  2018-05-26                Emirates     True
# 3684        Vladyslav Puzankov  2018-04-16                Emirates     True
# 3693             Clifford Kwok  2018-04-06                Emirates     True
# 3772                 N Jackson  2017-12-31                Emirates     True
# 3798                   D Halim  2017-12-04                Emirates     True
# 3812                S Merseame  2017-11-24                Emirates     True
# 4026            Smitha Prakash  2017-01-07                Emirates    False
# 4532                   M Balem  2023-09-06        Turkish Airlines     True
# 4535         Sertan Kocdeviren  2023-09-03        Turkish Airlines     True
# 5124                T Maraleva  2020-09-01        Turkish Airlines     True
# 5404                  J Calson  2019-05-24        Turkish Airlines     True
# 5513                H Mazaresh  2019-01-18        Turkish Airlines     True
# 5661            mark durbridge  2018-07-02        Turkish Airlines     True
# 6061                  R Kammas  2016-05-08        Turkish Airlines    False
# 7010              Darryl Manco  2020-02-09  Cathay Pacific Airways     True
# 7083                     H Gan  2019-08-20  Cathay Pacific Airways     True
# 7274                  N Sacina  2018-06-18  Cathay Pacific Airways     True
# 8078                 Julia Lee  2016-12-13              Korean Air     True
#
#                                                 Reviews Type of Traveller  \
# 380     London to Christchurch via Singapore. London...      Solo Leisure
# 428     We have flown multiple times via Singapore a...    Couple Leisure
# 487     I cannot believe that this flight was the ex...      Solo Leisure
# 560     Dubai to Singapore, with business class seat...          Business
# 1996    Bangalore to Nice via Doha. My experience fr...          Business
# 2505    Amman to Kuala Lumpur via Doha. A very forge...      Solo Leisure
# 2520    Beirut to Bangkok via Doha on Qatar Airways....          Business
# 2552    I returned from London Heathrow to Shanghai ...      Solo Leisure
# 2560    Manchester to Doha with Qatar Airways. 9am d...    Couple Leisure
# 2594    Copenhagen to Melbourne visa Doha return. Th...      Solo Leisure
# 2986    I can’t believe I’m writing this about Emira...    Couple Leisure
# 3359    Colombo to Zurich via Dubai. The last time I...    Family Leisure
# 3549    Madrid to Male via Dubai. I have never flown...    Family Leisure
# 3567    Dubai to Johannesburg. Emirates is a joke. W...          Business
# 3572    Toronto to Beirut via Dubai. What is the big...          Business
# 3592    Kuwait to Lyon return via Dubai. I usually f...      Solo Leisure
# 3661    Amsterdam to Melbourne via Dubai with Emirat...      Solo Leisure
# 3684    Sydney to Christchurch. Incompetence of Emir...    Couple Leisure
# 3693   Terrible service. Crew members were all too p...    Family Leisure
# 3772   Jakarta to London via Dubai. This is the firs...      Solo Leisure
# 3798    Glasgow to Dubai. Terrible seats that were t...    Family Leisure
# 3812    Zürich to Phuket via Dubai. I had high expec...    Couple Leisure
# 4026    Seattle to Thiruvananthapuram via Dubai.  I ...    Family Leisure
# 4532    As someone who has been a loyal Turkish Airl...          Business
# 4535    I had to book in an emergency asap so only a...          Business
# 5124    Turkish Airlines (THY) used to have one of t...          Business
# 5404    Kiev to Male via Istanbul. Two days lost and...    Couple Leisure
# 5513    Mumbai to Los Angeles via Istanbul. The esti...      Solo Leisure
# 5661   Istanbul to Manila. Flying business class for...      Solo Leisure
# 6061    Antalya to Frankfurt via Istanbul. Out of 4 ...          Business
# 7010   Los Angeles to Bangkok via Hong Kong. Travel ...    Couple Leisure
# 7083    Madrid to Hong Kong. On my Palma to Madrid f...      Solo Leisure
# 7274    Manila to Zurich via Hong Kong. I've been fl...    Couple Leisure
# 8078    Hong Kong to Nadi, Fiji via Seoul. It was my...      Solo Leisure
#
#          Month Flown                                      Route  \
# 380     October 2019                  Singapore to Johannesburg
# 428      August 2019                     Melbourne to Singapore
# 487       March 2019                     Singapore to Melbourne
# 560    December 2018  Barcelona to Manila via Milan / Singapore
# 1996   November 2018                         Doha to Manchester
# 2505  September 2016                         BRU to NRT via DOH
# 2520       July 2016                         DXB to KUL via DOH
# 2552        May 2016                         PSA to AKL via DOH
# 2560      April 2016                         PSA to AKL via DOH
# 2594   February 2016                         DXB to LHR via DOH
# 2986    January 2023             Newcastle to Nairobi via Dubai
# 3359       July 2019           Dubai to Melbourne via Singapore
# 3549   November 2018                      Brisbane to Singapore
# 3567  September 2018                 Sydney to Athens via Dubai
# 3572  September 2018          Johannesburg to Kolkata via Dubai
# 3592     August 2018                           Newark to Athens
# 3661        May 2018                       Bangkok to Hong Kong
# 3684      April 2018          Atlanta to Dubai via New York JFK
# 3693      April 2018                            Dubai to Mumbai
# 3772   December 2017           London to Kuala Lumpur via Dubai
# 3798    October 2017                             Milan to Dubai
# 3812   November 2017                            Dubai to London
# 4026    January 2017                         ISB to BLQ via DXB
# 4532      April 2023               Dubai to Madrid via Istanbul
# 4535     August 2023             Bali to Amsterdam via Istanbul
# 5124     August 2020                         Ankara to New York
# 5404        May 2019                      Istanbul to Singapore
# 5513    January 2019      New York to Thessaloniki via Istanbul
# 5661        May 2018                    Istanbul to Duesseldorf
# 6061        May 2016                                 SFO to IST
# 7010    January 2020       Los Angeles to Bangkok via Hong Kong
# 7083     August 2019                        Madrid to Hong Kong
# 7274       June 2018             Manila to Zurich via Hong Kong
# 8078   December 2016                         HKG to NAN via ICN
#
#                Class  ...  Inflight Entertainment  Value For Money  \
# 380   Business Class  ...                       5                1
# 428   Business Class  ...                       4                1
# 487    Economy Class  ...                       5                1
# 560   Business Class  ...                       3                2
# 1996   Economy Class  ...                       5                1
# 2505  Business Class  ...                       3                3
# 2520   Economy Class  ...                       5                5
# 2552  Business Class  ...                       4                4
# 2560  Business Class  ...                       3                5
# 2594  Business Class  ...                       4                5
# 2986  Business Class  ...                       3                1
# 3359   Economy Class  ...                       2                1
# 3549   Economy Class  ...                       4                1
# 3567   Economy Class  ...                       3                1
# 3572  Business Class  ...                       4                1
# 3592  Business Class  ...                       5                2
# 3661   Economy Class  ...                       3                1
# 3684   Economy Class  ...                       4                1
# 3693   Economy Class  ...                       5                1
# 3772  Business Class  ...                       5                1
# 3798   Economy Class  ...                       5                2
# 3812   Economy Class  ...                       5                2
# 4026   Economy Class  ...                       5                1
# 4532   Economy Class  ...                       5                1
# 4535   Economy Class  ...                       5                2
# 5124  Business Class  ...                       4                1
# 5404   Economy Class  ...                       3                3
# 5513   Economy Class  ...                       4                2
# 5661  Business Class  ...                       3                1
# 6061   Economy Class  ...                       4                1
# 7010  Business Class  ...                       5                1
# 7083   Economy Class  ...                       4                3
# 7274   Economy Class  ...                       5                3
# 8078   Economy Class  ...                       3                2
#
#       Overall Rating  Recommended  Sentiment  \
# 380                1           no          1
# 428                1           no          1
# 487                1           no          1
# 560                1           no          1
# 1996               1           no          1
# 2505               1           no          1
# 2520               1          yes          1
# 2552               1          yes          1
# 2560               1          yes          1
# 2594               1          yes          1
# 2986               1           no          1
# 3359               1           no          1
# 3549               1           no          1
# 3567               1           no          1
# 3572               1           no          1
# 3592               1           no          1
# 3661               1           no          1
# 3684               1           no          1
# 3693               1           no          1
# 3772               1           no          1
# 3798               1           no          1
# 3812               1           no          1
# 4026               1           no          1
# 4532               1           no          1
# 4535               1           no          1
# 5124               1           no          1
# 5404               1           no          1
# 5513               1           no          1
# 5661               1           no          1
# 6061               1           no          1
# 7010               1           no          1
# 7083               1           no          1
# 7274               1           no          1
# 8078               1           no          1
#
#                                               Reviews_1  \
# 380   london christchurch via singapor. london singa...
# 428   we flown multipl time via singapor airlin occa...
# 487   believ flight exact opposit last flight sia, w...
# 560   dubai singapor, busi class seat 12a, cabin ama...
# 1996  bangalor nice via doha. my experi great comfor...
# 2505  amman kuala lumpur via doha. forgett check, lo...
# 2520  beirut bangkok via doha qatar airway. second t...
# 2552  return london heathrow shanghai qatar airway. ...
# 2560  manchest doha qatar airway. 9am departur- boar...
# 2594  copenhagen melbourn visa doha return. thi fant...
# 2986  believ write emir sinc fli year custom servic ...
# 3359  colombo zurich via dubai. the last time flew e...
# 3549  madrid male via dubai. never flown emir last o...
# 3567  dubai johannesburg. emir joke. we given```````...
# 3572  toronto beirut via dubai. what big fuss emir? ...
# 3592  kuwait lyon return via dubai. usual fli qatar ...
# 3661  amsterdam melbourn via dubai emir may 2018. it...
# 3684  sydney christchurch. incompet emir check-in pe...
# 3693  terribl servic. crew member proud serv custom-...
# 3772  jakarta london via dubai. thi first time took ...
# 3798  glasgow dubai. terribl seat tight good sleep, ...
# 3812  zürich phuket via dubai. high expect sinc hear...
# 4026  seattl thiruvananthapuram via dubai. travel ki...
# 4532  as someon loyal turkish airlin custom consider...
# 4535  book emerg asap avail airlin specifi date turk...
# 5124  turkish airlin( thi) use one best busi class s...
# 5404  kiev male via istanbul. two day lost headach w...
# 5513  mumbai lo angel via istanbul. the estim depart...
# 5661  istanbul manila. fli busi class firstli mean s...
# 6061  antalya frankfurt via istanbul. out airplan fl...
# 7010  lo angel bangkok via hong kong. travel gift. e...
# 7083  madrid hong kong. on palma madrid flight catha...
# 7274  manila zurich via hong kong. fli cathay pacif ...
# 8078  hong kong nadi, fiji via seoul. it first fligh...
#
#      vader_polarity_compound  \
# 380                   0.9818
# 428                   0.9501
# 487                   0.9758
# 560                   0.9497
# 1996                  0.9840
# 2505                  0.9501
# 2520                  0.9814
# 2552                  0.9628
# 2560                  0.9612
# 2594                  0.9670
# 2986                  0.9616
# 3359                  0.9719
# 3549                  0.9691
# 3567                  0.9531
# 3572                  0.9623
# 3592                  0.9552
# 3661                  0.3798
# 3684                  0.9657
# 3693                  0.9432
# 3772                  0.8834
# 3798                  0.9432
# 3812                 -0.6631
# 4026                  0.9876
# 4532                  0.9485
# 4535                  0.9274
# 5124                  0.9809
# 5404                  0.6476
# 5513                  0.9623
# 5661                  0.9509
# 6061                  0.9618
# 7010                  0.9896
# 7083                  0.9666
# 7274                  0.9260
# 8078                  0.9050
#
#                                   vader_polarity_scores  \
# 380   {'neg': 0.069, 'neu': 0.688, 'pos': 0.243, 'co...
# 428   {'neg': 0.024, 'neu': 0.834, 'pos': 0.141, 'co...
# 487   {'neg': 0.038, 'neu': 0.737, 'pos': 0.225, 'co...
# 560   {'neg': 0.044, 'neu': 0.758, 'pos': 0.198, 'co...
# 1996  {'neg': 0.0, 'neu': 0.447, 'pos': 0.553, 'comp...
# 2505  {'neg': 0.022, 'neu': 0.735, 'pos': 0.243, 'co...
# 2520  {'neg': 0.0, 'neu': 0.639, 'pos': 0.361, 'comp...
# 2552  {'neg': 0.0, 'neu': 0.591, 'pos': 0.409, 'comp...
# 2560  {'neg': 0.035, 'neu': 0.811, 'pos': 0.154, 'co...
# 2594  {'neg': 0.028, 'neu': 0.814, 'pos': 0.158, 'co...
# 2986  {'neg': 0.058, 'neu': 0.723, 'pos': 0.219, 'co...
# 3359  {'neg': 0.076, 'neu': 0.745, 'pos': 0.18, 'com...
# 3549  {'neg': 0.084, 'neu': 0.742, 'pos': 0.175, 'co...
# 3567  {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compou...
# 3572  {'neg': 0.015, 'neu': 0.788, 'pos': 0.197, 'co...
# 3592  {'neg': 0.042, 'neu': 0.759, 'pos': 0.198, 'co...
# 3661  {'neg': 0.07, 'neu': 0.833, 'pos': 0.096, 'com...
# 3684  {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compou...
# 3693  {'neg': 0.0, 'neu': 0.757, 'pos': 0.243, 'comp...
# 3772  {'neg': 0.021, 'neu': 0.862, 'pos': 0.118, 'co...
# 3798  {'neg': 0.067, 'neu': 0.495, 'pos': 0.438, 'co...
# 3812  {'neg': 0.138, 'neu': 0.742, 'pos': 0.12, 'com...
# 4026  {'neg': 0.013, 'neu': 0.788, 'pos': 0.199, 'co...
# 4532  {'neg': 0.072, 'neu': 0.745, 'pos': 0.184, 'co...
# 4535  {'neg': 0.029, 'neu': 0.761, 'pos': 0.21, 'com...
# 5124  {'neg': 0.023, 'neu': 0.859, 'pos': 0.118, 'co...
# 5404  {'neg': 0.06, 'neu': 0.857, 'pos': 0.083, 'com...
# 5513  {'neg': 0.042, 'neu': 0.812, 'pos': 0.146, 'co...
# 5661  {'neg': 0.032, 'neu': 0.829, 'pos': 0.139, 'co...
# 6061  {'neg': 0.055, 'neu': 0.793, 'pos': 0.152, 'co...
# 7010  {'neg': 0.026, 'neu': 0.845, 'pos': 0.129, 'co...
# 7083  {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'comp...
# 7274  {'neg': 0.033, 'neu': 0.807, 'pos': 0.16, 'com...
# 8078  {'neg': 0.125, 'neu': 0.679, 'pos': 0.196, 'co...
#
#      textblob_polarity_compound  Afinn_polarity_compound
# 380                    0.271795                     19.0
# 428                    0.032937                     14.0
# 487                    0.128333                     18.0
# 560                    0.220833                     15.0
# 1996                   0.685714                     28.0
# 2505                   0.378125                     13.0
# 2520                   0.273535                     20.0
# 2552                   0.513333                     18.0
# 2560                   0.232051                     17.0
# 2594                   0.196778                     14.0
# 2986                   0.223380                     13.0
# 3359                   0.077536                     19.0
# 3549                   0.176952                     14.0
# 3567                   0.176587                     12.0
# 3572                   0.163333                     12.0
# 3592                   0.163690                     12.0
# 3661                   0.078571                     13.0
# 3684                   0.383333                     19.0
# 3693                   0.136667                     12.0
# 3772                   0.155495                     12.0
# 3798                   0.404252                     12.0
# 3812                   0.195134                     12.0
# 4026                   0.249915                     25.0
# 4532                   0.125641                     16.0
# 4535                   0.000000                     12.0
# 5124                   0.165474                     14.0
# 5404                   0.138745                     23.0
# 5513                   0.101754                     17.0
# 5661                   0.108036                     12.0
# 6061                   0.145455                     14.0
# 7010                   0.029415                     27.0
# 7083                   0.091667                     12.0
# 7274                   0.168939                     15.0
# 8078                   0.092121                     15.0
#
# [34 rows x 23 columns]

# %%
pd.set_option('display.max_colwidth', None)

obs = data.loc[8014]
print(obs[['Title', 'Reviews']])
# Out:
# Title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   nickel and dime culture
# Reviews      Los Angeles to Chiang Mai via Seoul. We decided to spend a little bit more for our flight to Thailand in exchange for a better service and were disappointed: We could have saved several hundreds of dollars if we had used a Chinese budget airline. What was good about Korean Air were the flight attendants who were super friendly and helpful, on our return flight to LAX they even carried my carry on bag for me, when they saw that I was holding our baby. The reason why we won't fly with Korean Air anymore: I had ordered a "vegetarian oriental meal" (not vegan, but vegetarian which isn't as restrictive) What I received was a joke: it looked like someone had emptied half a can of peas into the aluminum container and thrown some bok choi leaves on top. No sauce, tofu, rice or potatoes. Horrible. My wife was still hungry after her meal and asked for a snack. The answer was: "we don't carry any snacks" (contrary to what their website says: "Snack Service A wide variety of snacks, such as samgak kimbop, cup ramen, pizza, and makkoli rice cakes, are served on long flights." The flight attendant explained: "we stopped offering cup ramen because of the smell" when my wife told him that she used to get ramen on previous flights.  I had one can of beer at the beginning of the flight and ordered a gin tonic several hours later. This drink spilled because my table was defective (the kind which you pull out from the armrest). When I asked for another drink they watered it down and advised me "this is your last drink, each passenger is allowed to have only 3 drinks". I was not the slightest little bit drunken and very surprised because even on low budget airlines like Air India nobody told me how many drinks I could have. This is obviously a policy which is supposed to save the airline money.  We both started to get a headache because of dehydration. When I asked for water, the flight attendant poured approximately 4 table spoons into a cup, I went back and forth several times between our seats and the pantry and each time they filled the cup only 50%. We were both thirsty during the entire flight. Before departure there was a bottle of water on each seat and as soon as the boarding was completed, they hurried to collect the water bottles from the vacant seats. (Probably in order to lock them up in the safe...) 5.) We had purchased an inflatable pillow which was specifically designed for air travel. As soon as my wife started to inflate the pillow, several flight attendants approached us saying that we were not allowed to use it.  Obviously Korean Air's management made decisions in order to save money and we felt this nickel and dime culture during the entire trip. If we had chosen a low cost Chinese airline, we may have received some kind of rude treatment but enough to eat and drink for several hundred Dollars less.
# Name: 8014, dtype: object

# %% [markdown]
# **Normalised AFINN**

# %%
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler(feature_range = (-1,1))

afinn_normalized_polarity = scaler.fit_transform(data["Afinn_polarity_compound"].to_numpy().reshape(-1, 1))

# %%
data["afinn_normalized_polarity"] = afinn_normalized_polarity.reshape(-1)
data[['Reviews_1', 'Afinn_polarity_compound', 'afinn_normalized_polarity']].describe()
# Out:
#        Afinn_polarity_compound  afinn_normalized_polarity
# count              7318.000000                7318.000000
# mean                  4.340394                  -0.234437
# std                   8.745917                   0.161961
# min                 -37.000000                  -1.000000
# 25%                  -2.000000                  -0.351852
# 50%                   4.000000                  -0.240741
# 75%                   9.000000                  -0.148148
# max                  71.000000                   1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8100 entries, 0 to 8099
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Title                       8100 non-null   object
#  1   Name                        8100 non-null   object
#  2   Review Date                 8100 non-null   object
#  3   Airline                     8100 non-null   object
#  4   Verified                    8100 non-null   object
#  5   Reviews                     8100 non-null   object
#  6   Type of Traveller           8100 non-null   object
#  7   Month Flown                 8100 non-null   object
#  8   Route                       8100 non-null   object
#  9   Class                       8100 non-null   object
#  10  Seat Comfort                8100 non-null   int64
#  11  Staff Service               8100 non-null   int64
#  12  Food & Beverages            8100 non-null   int64
#  13  Inflight Entertainment      8100 non-null   int64
#  14  Value For Money             8100 non-null   int64
#  15  Overall Rating              8100 non-null   int64
#  16  Recommended                 8100 non-null   object
#  17  Sentiment                   8100 non-null   int64
#  18  Reviews_1                   8100 non-null   object
#  19  vader_polarity_compound     8100 non-null   float64
#  20  vader_polarity_scores       8100 non-null   object
#  21  textblob_polarity_compound  8100 non-null   float64
#  22  Afinn_polarity_compound     8100 non-null   float64
#  23  afinn_normalized_polarity   8100 non-null   float64
# dtypes: float64(4), int64(7), object(13)
# memory usage: 1.5+ MB

# %% [markdown]
# ## Comparing Methods

# %%
compare = ['vader_polarity_compound', 'textblob_polarity_compound', 'afinn_normalized_polarity']

# %%
means_by_tag = data.groupby('Sentiment')[compare].mean()

# Plot the means
ax = means_by_tag.plot(kind='bar', figsize=(10, 6))
plt.title('Mean Polarity Compound per Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Mean Polarity Compound')

# Change the legend location to the upper right
ax.legend(title='Polarity Compound', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
means_by_tag = data.groupby('Sentiment')[compare].max()

# Plot the means
ax = means_by_tag.plot(kind='bar', figsize=(10, 6))
plt.title('Max Polarity Compound per Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Max Polarity Compound')

# Change the legend location to the upper right
ax.legend(title='Polarity Compound', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
